# %% [markdown]
# 10/07/2017
# ### testing the behaviour of the newly defined "GenSimQMD.py" for both IQLE and QLE

# %%
# %matplotlib inline

import qinfer as qi
#import qutip as qt
import numpy as np
import scipy as sp
from IPython.display import display, Math, Latex
from functools import partial
import matplotlib.pyplot as plt
import importlib as imp

# %%
import datetime
import os as os
import time as time

# %%
import logging as logging
import sys

# %run LoggingCode.py

# %%
# tell the user where files will be saved
dire = os.getcwd()
dire = dire+"/tests/T"
dire = os.path.normpath(dire)
print('Files will be saved in:')
print(dire)
# Out:
# Files will be saved in:
# C:\Users\ag15141\Local Documents\Cloud\Dropbox (Qsim)\QML_share_stateofart\QMD\testing_notebooks\tests\T

# %%
# Add personalized library to PYTHONPATH
sys.path.append(os.path.join("..","Libraries","QML_lib"))

# %%
from Norms import *
from IOfuncts import *
from EvalLoss import *

import ProbeStates as pros
import multiPGH as mpgh
import GenSimQMD as gsi
import Evo as evo
import Distrib as distr

# %% [markdown]
# # Results from trivial step-by-step implementation

# %%
imp.reload(pros)
imp.reload(mpgh)
imp.reload(gsi)
imp.reload(evo)
imp.reload(distr)
# Out:
# <module 'Distrib' from '..\\Libraries\\QML_lib\\Distrib.py'>

# %%
# Decide the size of the problem

#oplist=np.array([evo.sigmax(), evo.sigmay(), evo.sigmaz()])
#oplist=np.array([evo.sigmay(), evo.sigmax()])
oplist=np.array([evo.sigmaz()])


true_params = np.array([0.3+np.random.rand(1)/2.5])
print('Chosen true_params: ' + str(true_params))

oplist=np.dot(1.0, oplist)
print('Oplist: ' + repr(oplist))
# Out:
# Chosen true_params: [[ 0.59469643]]
# Oplist: array([[[ 1.,  0.],
#         [ 0., -1.]]])

# %%
#Probelist
probelist = list(map(lambda x: pros.def_randomprobe(oplist), range(15)))

sigx = 0.15
sigy = 0.15
sigz = 0.15

offset = 0.2
prior = distr.MultiVariateUniformDistribution(len(oplist))

# probelist can be either:
# - [probestate] : in this case the probe is constantly selected from the state provided
# - "eiglist" or "probelist": in this case, the probe is selected sequentially (eventually with some weighting) among the list provided

model = gsi.GenSimQMD(oplist=oplist, modelparams=true_params, probecounter = probecounter,  
                      true_oplist = oplist, trueparams=true_params,
                      probelist=probelist, trotter = False, IQLE=True)

n_particles = 1000
n_experiments = 100

updater = qi.SMCUpdater(model, n_particles, prior, resample_thresh=0.7, resampler = qi.LiuWestResampler(a=0.98), debug_resampling=True)

inv_field = [item[0] for item in model.expparams_dtype[1:] ]
print('Inversion fields are: ' + str(inv_field))
heuristic = mpgh.multiPGH(updater, oplist, inv_field=inv_field)
experiment = heuristic()
print('Heuristic output:' + repr(experiment))

expparams = np.empty((1, ), dtype=model.expparams_dtype)

print('Initialization Ready')
# Out:
# Inversion fields are: ['w_1']
# Heuristic output:array([(0.39893683243914857, -0.2842422834034488)],
#       dtype=[('t', '<f8'), ('w_1', '<f8')])
# Initialization Ready

# %%
datum = model.simulate_experiment(true_params, experiment)
print(repr(datum))
# Out:
# 0

# %%
updater.update(datum, experiment)

# %%
# probecounter for the choice of the state
probecounter = 0

track_loss = np.empty(n_experiments)
track_cov = np.empty(n_experiments)
track_time = np.empty(n_experiments)

track_particle_locs = np.empty([n_particles, len(true_params[0]), n_experiments])
track_particle_wght = np.empty([n_particles, n_experiments])


for idx_experiment in range(n_experiments):
    
    experiment = heuristic()
    #print('Chosen experiment: ' + repr(experiment))
    
    if idx_experiment == 0:
        print('Initial time selected > ' + str(experiment[0][0]))
    if idx_experiment == n_experiments-1:
        print('Final time selected > ' + str(experiment[0][0]))
    
    track_time[idx_experiment] = experiment[0][0]
    
    datum = model.simulate_experiment(true_params, experiment)
    #print(repr(datum))
    updater.update(datum, experiment)
    heuristic = mpgh.multiPGH(updater, oplist, inv_field=inv_field)
    
    track_cov[idx_experiment] = np.linalg.norm(updater.est_covariance_mtx())
    
    track_particle_locs[:, :, idx_experiment] = updater.particle_locations
    track_particle_wght[:, idx_experiment] = updater.particle_weights

    new_eval = updater.est_mean()
    
    new_loss = eval_loss(model, new_eval, true_params)
    track_loss[idx_experiment] = new_loss[0]
# Out:
# Initial time selected > 2.58801453653
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00564128  0.00055817 -0.00073288]. Norm change in cov: 0.0013184733990737104.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00244474 -0.000803   -0.0049302 ]. Norm change in cov: 0.001885580193653694.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00338727 -0.00035577 -0.00130209]. Norm change in cov: 0.0009195365839968691.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00037607  0.00067746  0.0011401 ]. Norm change in cov: 0.0007951375584079787.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.0008463  -0.00126275  0.00311968]. Norm change in cov: 0.0006795629642539631.
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00077415 -0.00068799  0.0039731 ]. Norm change in cov: 0.0006630630205596699.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00074731  0.00178457  0.00135058]. Norm change in cov: 0.00020954465102185447.
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00163634  0.00106543  0.00352648]. Norm change in cov: 0.0008292502140391771.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00040032  0.00116965 -0.00030894]. Norm change in cov: 0.0001613494396677454.
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00034494  0.0017378  -0.00016187]. Norm change in cov: 0.0003414994006587407.
# qinfer.smc - DEBUG - Resampling changed mean by [  9.74474222e-05   2.82145907e-04  -4.31169429e-03]. Norm change in cov: 0.00023220846380947864.
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.0020593   0.00054934 -0.00197463]. Norm change in cov: 0.00046741431127650726.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.0028562  -0.00054692  0.0017923 ]. Norm change in cov: 0.00010676902529766203.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00015551 -0.0004089  -0.00168118]. Norm change in cov: 0.0001224589925620654.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00113466  0.00013441  0.00037914]. Norm change in cov: 0.00038911305945557237.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00018273  0.00148081  0.00155127]. Norm change in cov: 0.0002884258748025034.
# qinfer.smc - DEBUG - Resampling changed mean by [ -9.80427328e-04   8.42165588e-04  -6.29401651e-05]. Norm change in cov: 0.00030232775079682317.
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00151273 -0.0001755  -0.00140959]. Norm change in cov: 0.00036705837952915677.
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00194464  0.00074754 -0.00237439]. Norm change in cov: 0.0004893774754631955.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00450003  0.00061704  0.00483795]. Norm change in cov: 0.0010874793081235552.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00246523  0.00065576  0.00516841]. Norm change in cov: 0.0009574588763171917.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00015037 -0.00050264  0.00089548]. Norm change in cov: 0.00037286138104293694.
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00382392 -0.00058291 -0.00432115]. Norm change in cov: 0.000840019728220545.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00268639 -0.00010212  0.00389642]. Norm change in cov: 0.001597298921395869.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00406853  0.00038677  0.00509319]. Norm change in cov: 0.0006979152036988803.
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00074322 -0.00281336 -0.00062459]. Norm change in cov: 0.00014768748097100453.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.
-06.
# qinfer.smc - DEBUG - Resampling changed mean by [ -1.20800802e-04   6.11917610e-05   2.41144599e-04]. Norm change in cov: 6.970890036167337e-06.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.0001119  -0.00026906  0.00033782]. Norm change in cov: 5.457545300757964e-06.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00017021 -0.00025547 -0.00025047]. Norm change in cov: 1.3716535549773793e-05.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00017021  0.00011204  0.00028432]. Norm change in cov: 8.801005040041312e-06.
# qinfer.smc - DEBUG - Resampling changed mean by [ -1.36640723e-04  -3.47159835e-04   6.94823161e-05]. Norm change in cov: 1.0165769153227524e-05.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00016651  0.00023607  0.00011736]. Norm change in cov: 1.5736707072561976e-05.
# qinfer.smc - DEBUG - Resampling changed mean by [ -9.96894811e-05   1.86905164e-04   4.15784153e-04]. Norm change in cov: 5.4269022062183586e-06.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00015916 -0.00035367  0.00012209]. Norm change in cov: 3.738156094478965e-06.
# qinfer.smc - DEBUG - Resampling changed mean by [ -3.91515097e-06  -3.07705119e-04  -1.11681697e-04]. Norm change in cov: 7.305758098255181e-06.
# qinfer.smc - DEBUG - Resampling changed mean by [ -1.45079010e-05   2.67640600e-04   4.74423384e-04]. Norm change in cov: 5.632060522133058e-06.
# qinfer.smc - DEBUG - Resampling changed mean by [  1.96346624e-05   1.48120974e-04  -7.31936927e-05]. Norm change in cov: 5.7332646949710655e-06.
# qinfer.smc - DEBUG - Resampling changed mean by [  1.29976987e-05   6.62450517e-05   2.67976073e-04]. Norm change in cov: 4.033016789343112e-06.
# qinfer.smc - DEBUG - Resampling changed mean by [  7.88867763e-05  -1.81544469e-04  -1.72964862e-04]. Norm change in cov: 1.2456145393181563e-06.
# qinfer.smc - DEBUG - Resampling changed mean by [ -8.77162083e-05   6.74534826e-05   4.12925989e-05]. Norm change in cov: 1.512504111665035e-06.
# qinfer.smc - DEBUG - Resampling changed mean by [ -1.87984042e-04  -9.53454930e-05  -7.64092616e-05]. Norm change in cov: 4.353618552975467e-06.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00014538 -0.00014548 -0.00023832]. Norm change in cov: 3.124029144814874e-06.
# qinfer.smc - DEBUG - Resampling changed mean by [  5.89420430e-05   5.14730926e-05  -2.25284925e-04]. Norm change in cov: 7.447381928674644e-06.
# qinfer.smc - DEBUG - Resampling changed mean by [ -4.79607471e-05  -8.57188076e-06  -5.89107257e-05]. Norm change in cov: 1.9241074678508374e-06.
# Final time selected > 149.395568309

# %%
plt.plot(track_time)
plt.xlabel('# of Measurements')
plt.ylabel('t from PGH')

plt.show()

# %% [markdown]
# ## use this only if real and simulated models coincide

# %%
plt.semilogy(track_loss, label='Q.L.')
plt.semilogy(track_cov, label='Cov. Norm.')
plt.legend()
plt.xlabel('# of Measurements')

filename = dire+str(timestamp)+"_Fig_QL_CovNorm_Npars_"+str(len(true_params[0]))+"_Nexp_"+str(n_experiments)+"_Nparts_"+str(n_particles)+".pdf"
print("Files to output:\n" + str(filename))

#plt.savefig(filename)

plt.show()
# Out:
# Files to output:
# C:\Users\ag15141\Local Documents\Cloud\Dropbox (Qsim)\Projects\CU4 chip\QHLandD\MultiPar_GenSim cleanup\tests\T_2017-05-12_18.58.04_Fig_QL_CovNorm_Npars_3_Nexp_200_Nparts_1000.pdf

# %% [markdown]
# ## use this only for 1D models

# %% [markdown]
# ## use this only for 2D models

# %%
timestep = 175

from mpl_toolkits.mplot3d import axes3d

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, axisbg="1.0")
ax = fig.gca(projection='3d')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.scatter(track_particle_locs[:,0,timestep], track_particle_locs[:,1,timestep],  track_particle_locs[:,2,timestep], c=track_particle_wght[:,timestep], cmap=plt.cm.RdYlGn)
filefigname1 = dire+str(timestamp)+"With_Trotter"+"_Distro_particles"+"_SteNum_"+str(timestep)+"_Npars_"+str(len(true_params[0]))+"_Nexp_"+str(n_experiments)+"_Nparts_"+str(n_particles)+".pdf"
#plt.savefig(filefigname1)
plt.show()
