# %% [markdown]
# 24/07/2017
#
# A. Gentile
#
# ### testing the behaviour of QMD for 2qubit NV hyperfine coupling Hamiltonian term
#
# - IQLE tested first
# - QLE follows in the notebook

# %% [markdown]
# ## Library uploading

# %%
# %matplotlib inline

import qinfer as qi
#import qutip as qt
import numpy as np
import scipy as sp
from IPython.display import display, Math, Latex
from functools import partial
import matplotlib.pyplot as plt
import importlib as imp

# %%
import datetime
import os as os
import time as time

# %%
import logging as logging
import sys

# %run LoggingCode.py

# %%
# tell the user where files will be saved
dire = os.getcwd()
dire = dire+"/tests/"
dire = os.path.normpath(dire)
print('Files will be saved in:')
print(dire)
# Out:
# Files will be saved in:
# C:\Users\ag15141\Local Documents\Cloud\Dropbox (Qsim)\QML_share_stateofart\QMD\testing_notebooks\tests

# %%
# Add personalized library to PYTHONPATH
sys.path.append(os.path.join("..","Libraries","QML_lib"))

# %%
from Norms import *
from IOfuncts import *
from EvalLoss import *

import ProbeStates as pros
import multiPGH as mpgh
import GenSimQMD as gsi
import Evo as evo
import Distrib as distr

# %%
import warnings as warnings

""" filter only the Weight Clipping warning """
#SET LEVEL WARNINGS TO 0 In FINAL VERSION
warnings.filterwarnings("ignore", message='Negative weights occured', category=RuntimeWarning)

# %% [markdown]
# ## Reload when needed

# %%
imp.reload(pros)
imp.reload(mpgh)
imp.reload(gsi)
imp.reload(evo)
imp.reload(distr)
# Out:
# <module 'Distrib' from '..\\Libraries\\QML_lib\\Distrib.py'>

# %% [markdown]
# # Choose model & parameters & probe states

# %%
spinlst = [evo.sigmax(),evo.sigmay(), evo.sigmaz()]

# %%
# Implement the NV centre spin- nuclear (iso)spin interaction term

oplist = np.array(list(map(lambda j: np.kron(spinlst[j],spinlst[j]), range(len(spinlst)))))
print('Oplist: ' + repr(oplist))
# Out:
# Oplist: array([[[ 0.+0.j,  0.+0.j,  0.+0.j,  1.+0.j],
#         [ 0.+0.j,  0.+0.j,  1.+0.j,  0.+0.j],
#         [ 0.+0.j,  1.+0.j,  0.+0.j,  0.+0.j],
#         [ 1.+0.j,  0.+0.j,  0.+0.j,  0.+0.j]],
#
#        [[ 0.+0.j,  0.-0.j,  0.-0.j, -1.+0.j],
#         [ 0.+0.j,  0.+0.j,  1.-0.j,  0.-0.j],
#         [ 0.+0.j,  1.-0.j,  0.+0.j,  0.-0.j],
#         [-1.+0.j,  0.+0.j,  0.+0.j,  0.+0.j]],
#
#        [[ 1.+0.j,  0.+0.j,  0.+0.j,  0.+0.j],
#         [ 0.+0.j, -1.+0.j,  0.+0.j,  0.+0.j],
#         [ 0.+0.j,  0.+0.j, -1.+0.j,  0.+0.j],
#         [ 0.+0.j,  0.+0.j,  0.+0.j,  1.+0.j]]])

# %%
# True params are chosen according to Felton et al. PHYSICAL REVIEW B 79, 075203 2009

true_params = np.array([[0.27, 0.27, 0.214]])
print('Chosen true_params: ' + str(true_params))

# quick test of the getH function, OK!
(np.tensordot(true_params, oplist, axes=1))
# Out:
# Chosen true_params: [[ 0.27   0.27   0.214]]
# array([[[ 0.214+0.j,  0.000+0.j,  0.000+0.j,  0.000+0.j],
#         [ 0.000+0.j, -0.214+0.j,  0.540+0.j,  0.000+0.j],
#         [ 0.000+0.j,  0.540+0.j, -0.214+0.j,  0.000+0.j],
#         [ 0.000+0.j,  0.000+0.j,  0.000+0.j,  0.214+0.j]]])

# %%
#Probelist

probelist = list(map(lambda x: pros.def_randomprobe(oplist), range(20)))
#probelist = [pros.choose_probe(oplist)]
#print('Chosen probe: ', repr(probelist))

# %% [markdown]
# Adopted random sampling of $| \Psi_{probe} \rangle$ for both the $\hat{S}$ and $\hat{I}$ operators

# %% [markdown]
# # Results from IQLE - Single Runs

# %%
prior = distr.MultiVariateUniformDistribution(len(oplist), DistroLimits=np.array([[0.1,0.4]]))

# probelist can be either:
# - [probestate] : in this case the probe is constantly selected from the state provided
# - "eiglist" or "probelist": in this case, the probe is selected sequentially (eventually with some weighting) among the list provided

probecounter = 0
invertize=True
trotterize=True
model = gsi.GenSimQMD(oplist=oplist, modelparams=true_params, probecounter = probecounter,  
                      true_oplist = oplist, trueparams=true_params,
                      probelist=probelist, 
                      trotter = trotterize, IQLE=invertize)

n_particles = 200
n_experiments = 150

# higher resample_threshold -> higher frequency of resampling
# higher a in LiuWest -> less "data scrambling", slower learning
updater = qi.SMCUpdater(model, n_particles, prior, resample_thresh=0.85, resampler = qi.LiuWestResampler(a=0.7), debug_resampling=True)

#IQLE already works well with resample_thresh=0.5, resampler = qi.LiuWestResampler(a=0.8)

inv_field = [item[0] for item in model.expparams_dtype[1:] ]
print('Inversion fields are: ' + str(inv_field))
heuristic = mpgh.multiPGH(updater, oplist, inv_field=inv_field)
experiment = heuristic()
print('Heuristic output:' + repr(experiment))

expparams = np.empty((1, ), dtype=model.expparams_dtype)

print('Initialization Ready')
# Out:
# Inversion fields are: ['w_1', 'w_2', 'w_3']
# Heuristic output:array([ (2.560992250273111, 0.10528920203921127, 0.22202267039585183, 0.2938702874231912)],
#       dtype=[('t', '<f8'), ('w_1', '<f8'), ('w_2', '<f8'), ('w_3', '<f8')])
# Initialization Ready

# %%
datum = model.simulate_experiment(true_params, experiment)
print(repr(datum))
# Out:
# 0

# %%
updater.update(datum, experiment)

# %%
start = time.clock()

# probecounter for the choice of the state
probecounter = 0

track_loss = np.empty(n_experiments)
track_cov = np.empty(n_experiments)
track_time = np.empty(n_experiments)

track_particle_locs = np.empty([n_particles, len(true_params[0]), n_experiments])
track_particle_wght = np.empty([n_particles, n_experiments])


for idx_experiment in range(n_experiments):
    
    experiment = heuristic()
    #print('Chosen experiment: ' + repr(experiment))
    
    if idx_experiment == 0:
        print('Initial time selected > ' + str(experiment[0][0]))
    if idx_experiment == n_experiments-1:
        print('Final time selected > ' + str(experiment[0][0]))
    
    track_time[idx_experiment] = experiment[0][0]
    
    datum = model.simulate_experiment(true_params, experiment)
    #print(repr(datum))
    updater.update(datum, experiment)
#     heuristic = mpgh.multiPGH(updater, oplist, inv_field=inv_field)
    
    track_cov[idx_experiment] = np.linalg.norm(updater.est_covariance_mtx())
    
    track_particle_locs[:, :, idx_experiment] = updater.particle_locations
    track_particle_wght[:, idx_experiment] = updater.particle_weights

    new_eval = updater.est_mean()
    
    new_loss = eval_loss(model, new_eval, true_params)
    track_loss[idx_experiment] = new_loss[0]
    
end = time.clock()

print("\n\nElapsed time:" + str(end-start) + " secs")
# Out:
# Initial time selected > 2.82898326557
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00013247  0.00711542 -0.00168654]. Norm change in cov: 0.0009578760274026361.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00293253  0.00118143  0.0010835 ]. Norm change in cov: 0.0013070582831872816.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00201417  0.0038705  -0.00180617]. Norm change in cov: 0.0008417325935343866.
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00442794  0.00478135  0.00367654]. Norm change in cov: 0.0011477093800295374.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00240154  0.00640281  0.00562242]. Norm change in cov: 0.0005569116967197402.
# C:\Program Files\Anaconda3\lib\site-packages\qinfer\smc.py:429: ApproximationWarning: Negative weights occured in particle approximation. Smallest weight observed == -1.0159733105292426e-17. Clipping weights.
#   warnings.warn("Negative weights occured in particle approximation. Smallest weight observed == {}. Clipping weights.".format(np.min(weights)), ApproximationWarning)
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00306729  0.01151833  0.01020236]. Norm change in cov: 0.0006717253969413296.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.0038182  -0.00188068 -0.00104888]. Norm change in cov: 0.0014940252408168638.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00822627  0.00112211  0.00542396]. Norm change in cov: 0.0018015892197249157.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.0037328  -0.00749049 -0.0056147 ]. Norm change in cov: 0.0011141306280188243.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00512762 -0.01050497 -0.00598861]. Norm change in cov: 0.0006718018989483158.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00020483 -0.00215808  0.00075706]. Norm change in cov: 0.0005823731751842329.
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00485713  0.00534217  0.00518154]. Norm change in cov: 0.0003316903295747987.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00412926 -0.00279512 -0.00137279]. Norm change in cov: 7.395445805255849e-05.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00069896 -0.00044485 -0.00025165]. Norm change in cov: 0.0001704836862890098.
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00261671  0.00357609  0.0040602 ]. Norm change in cov: 0.0002564632020229298.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00286947 -0.0012465  -0.00040732]. Norm change in cov: 0.00020381617435047484.
# qinfer.smc - DEBUG - Resampling changed mean by [  1.55389137e-03  -6.84382915e-04  -6.24576212e-05]. Norm change in cov: 0.00010262645535415861.
# qinfer.smc - DEBUG - Resampling changed mean by [  1.71997489e-03  -4.97226095e-05   1.81505267e-03]. Norm change in cov: 7.065601302836842e-05.
# qinfer.smc - DEBUG - Resampling changed mean by [  1.77583693e-05  -2.33862662e-04   3.33647923e-04]. Norm change in cov: 6.646569308683099e-05.
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00158697  0.00048052  0.00073699]. Norm change in cov: 4.812534553899761e-05.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00072591  0.00188432  0.00125301]. Norm change in cov: 6.093765002654461e-05.
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00114971 -0.0003081  -0.00023087]. Norm change in cov: 5.953704951326365e-05.
# qinfer.smc - DEBUG - Resampling changed mean by [  3.01845490e-06   8.51642003e-04  -1.17608633e-04]. Norm change in cov: 4.885275537646525e-05.
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00083708  0.00041004  0.0011393 ]. Norm change in cov: 6.0365262237590464e-05.
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00143855  0.00157695  0.00053758]. Norm change in cov: 4.9433775422526535e-05.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00021685 -0.00034976 -0.0004958 ]. Norm change in cov: 2.2071443302927677e-05.
# qinfer.smc - DEBUG - Resampling changed mean by [-0.00031944  0.00013617 -0.00071189]. Norm change in cov: 2.2774833988942907e-05.
# qinfer.smc - DEBUG - Resampling changed mean by [  1.47490252e-03   7.95809684e-05   1.88147779e-04]. Norm change in cov: 2.1908350880322187e-05.
# qinfer.smc - DEBUG - Resampling changed mean by [ 0.00011415 -0.00038196 -0.00063858]. Norm change in cov: 4.2148472662008596e-05.
# Final time selected > 32.4047649504
#
#
# Elapsed time:12.637488024032791 secs

# %%
plt.plot(track_time)
plt.xlabel('# of Measurements')
plt.ylabel('t from PGH')

plt.show()

# %% [markdown]
# ## use this only if real and simulated models coincide

# %%
timestamp = str(datetime.datetime.now()).split('.')[0]
timestamp = "_"+timestamp.replace(" ", "_")
timestamp = timestamp.replace(":", ".")

labelize = '_IQLE' if invertize == True else '_QLE'

plt.semilogy(track_loss, label='Q.L.')
plt.semilogy(track_cov, label='Cov. Norm.')
plt.legend()
plt.xlabel('# of Measurements')
plt.title(r"2qubits ($H_f$: $\hat{I}=1/2$), Uniform prior "+ labelize)

plt.show()

# %%
filefigname = dire+labelize+"_Trotter-"+str(trotterize)+"_2qubits(Hf_I-0.5)"+"_Nparts_"+str(n_particles)+"___"+str(timestamp)+".pdf"
filefigname = os.path.normpath(filefigname)
print(filefigname)
#plt.savefig(filefigname)
# Out:
# C:\Users\ag15141\Local Documents\Cloud\Dropbox (Qsim)\QML_share_stateofart\QMD\testing_notebooks\tests_IQLE_Trotter-True_2qubits(Hf_I-0.5)_Nparts_200____2017-07-24_19.49.08.pdf

# %% [markdown]
# # Multiple tests for IQLE

# %%
prior = distr.MultiVariateUniformDistribution(len(oplist), DistroLimits=np.array([[0.1,0.4]]))

# probelist can be either:
# - [probestate] : in this case the probe is constantly selected from the state provided
# - "eiglist" or "probelist": in this case, the probe is selected sequentially (eventually with some weighting) among the list provided

probecounter = 0
invertize=True
trotterize=True
model = gsi.GenSimQMD(oplist=oplist, modelparams=true_params, probecounter = probecounter,  
                      true_oplist = oplist, trueparams=true_params,
                      probelist=probelist, 
                      trotter = trotterize, IQLE=invertize)

n_particles = 150
n_experiments = 150

# higher resample_threshold -> higher frequency of resampling
# higher a in LiuWest -> less "data scrambling", slower learning

resamp_t = 0.85
resamp_a = 0.7
extra_updater_args={'resample_thresh': 0.7, 'resampler': qi.LiuWestResampler(a=0.8), 'debug_resampling': False}
updater = qi.SMCUpdater(model, n_particles, prior, **extra_updater_args)


#IQLE already works well with resample_thresh=0.5, resampler = qi.LiuWestResampler(a=0.8)

inv_field = [item[0] for item in model.expparams_dtype[1:] ]
print('Inversion fields are: ' + str(inv_field))
heuristic = mpgh.multiPGH(updater, oplist, inv_field=inv_field)
experiment = heuristic()
print('Heuristic output:' + repr(experiment))

expparams = np.empty((1, ), dtype=model.expparams_dtype)

print('Initialization Ready')
# Out:
# Inversion fields are: ['w_1', 'w_2', 'w_3']
# Heuristic output:array([ (1.8079126203198492, 0.3876200482869998, 0.18984941416954615, 0.29942821834231603)],
#       dtype=[('t', '<f8'), ('w_1', '<f8'), ('w_2', '<f8'), ('w_3', '<f8')])
# Initialization Ready

# %%
n_trials =2

start = time.clock()

# probecounter for the choice of the state
probecounter = 0
track_loss = np.empty([n_trials, n_experiments])

for trial in range(n_trials):
    
    for idx_experiment in range(n_experiments):

        experiment = heuristic()

        datum = model.simulate_experiment(true_params, experiment)
        updater.update(datum, experiment)
    #     heuristic = mpgh.multiPGH(updater, oplist, inv_field=inv_field)

        new_eval = updater.est_mean()

        new_loss = eval_loss(model, new_eval, true_params)
        track_loss[trial, idx_experiment] = new_loss[0]
    
end = time.clock()

print("\n\nElapsed time:" + str(end-start) + " secs")
# Out:
# Elapsed time:19.340357686502102 secs

# %%
timestamp = str(datetime.datetime.now()).split('.')[0]
timestamp = "_"+timestamp.replace(" ", "_")
timestamp = timestamp.replace(":", ".")

labelize = '_IQLE' if invertize == True else '_QLE'

# %%
bayes_risk = track_loss.mean(axis=0)

plt.semilogy(bayes_risk, label='{} particles'.format(n_particles))

plt.title('Uniform Prior, Resamp. threshold = ' +str(resamp_t) + ', Resamp. a = ' +str(resamp_a)+ '\n')
plt.xlabel('# of Measurements')
plt.ylabel('Bayes Risk')
plt.legend()

filefigname = dire+labelize+"_Ntests_"+str(n_trials)+"_Trotter-"+str(trotterize)+"_2qubits(Hf_I-0.5)"+"_Nparts_"+str(n_particles)+"___"+str(timestamp)+".pdf"
filefigname = os.path.normpath(filefigname)

print('Picture saved in'+filefigname)

plt.show()
# Out:
# Picture saved inC:\Users\ag15141\Local Documents\Cloud\Dropbox (Qsim)\QML_share_stateofart\QMD\testing_notebooks\tests_IQLE_Ntests_2_Trotter-True_2qubits(Hf_I-0.5)_Nparts_150____2017-07-25_11.05.14.pdf

# %% [markdown]
# # Tests using perf_test_multiple

# %%
prior = distr.MultiVariateUniformDistribution(len(oplist), DistroLimits=np.array([[0.1,0.4]]))

# probelist can be either:
# - [probestate] : in this case the probe is constantly selected from the state provided
# - "eiglist" or "probelist": in this case, the probe is selected sequentially (eventually with some weighting) among the list provided

probecounter = 0
invertize=True
trotterize=True
model = gsi.GenSimQMD(oplist=oplist, modelparams=true_params, probecounter = probecounter,  
                      true_oplist = oplist, trueparams=true_params,
                      probelist=probelist, 
                      trotter = trotterize, IQLE=invertize)

n_particles = 150
n_experiments = 150

# higher resample_threshold -> higher frequency of resampling
# higher a in LiuWest -> less "data scrambling", slower learning

resamp_t = 0.85
resamp_a = 0.7
extra_updater_args={'resample_thresh': 0.7, 'resampler': qi.LiuWestResampler(a=0.8), 'debug_resampling': False}
updater = qi.SMCUpdater(model, n_particles, prior, **extra_updater_args)


#IQLE already works well with resample_thresh=0.5, resampler = qi.LiuWestResampler(a=0.8)

inv_field = [item[0] for item in model.expparams_dtype[1:] ]
print('Inversion fields are: ' + str(inv_field))
heuristic = mpgh.multiPGH(updater, oplist, inv_field=inv_field)
experiment = heuristic()
print('Heuristic output:' + repr(experiment))

expparams = np.empty((1, ), dtype=model.expparams_dtype)

print('Initialization Ready')
# Out:
# Inversion fields are: ['w_1', 'w_2', 'w_3']
# Heuristic output:array([ (3.6012385338020594, 0.20447889782065246, 0.21596405293084953, 0.2559116505893788)],
#       dtype=[('t', '<f8'), ('w_1', '<f8'), ('w_2', '<f8'), ('w_3', '<f8')])
# Initialization Ready

# %%
start = time.clock()

n_trials = 2
perf = qi.perf_test_multiple(model=model, n_trials = 2, n_particles=n_particles, prior=prior,
        n_exp=n_experiments, true_mps = true_params, heuristic_class=partial(mpgh.multiPGH, inv_field=inv_field, t_field='t'), 
                    extra_updater_args = extra_updater_args)

end=time.clock()
print('elapsed time: ' + str(end-start))
# Out:
# elapsed time: 19.355818348070898

# %%
bayes_risk = perf['loss'].mean(axis=0)

plt.semilogy(bayes_risk, label='{} particles'.format(n_particles))

plt.title('Uniform Prior, Resamp. threshold = ' +str(resamp_t) + ', Resamp. a = ' +str(resamp_a)+ '\n')
plt.xlabel('# of Measurements')
plt.ylabel('Bayes Risk')
plt.legend()

filefigname = dire+labelize+"_Ntests_"+str(n_trials)+"_Trotter-"+str(trotterize)+"_2qubits(Hf_I-0.5)"+"_Nparts_"+str(n_particles)+"___"+str(timestamp)+".pdf"
filefigname = os.path.normpath(filefigname)

print('Picture saved in'+filefigname)

plt.show()
# Out:
# Picture saved inC:\Users\ag15141\Local Documents\Cloud\Dropbox (Qsim)\QML_share_stateofart\QMD\testing_notebooks\tests_IQLE_Ntests_2_Trotter-True_2qubits(Hf_I-0.5)_Nparts_200____2017-07-25_10.41.17.pdf
