# %%
import numpy as np
import itertools as itr

import os as os
import sys as sys 
import pandas as pd
import warnings
import time as time
import random
from __future__ import print_function # so print doesn't show brackets

sys.path.append(os.path.join("..","Libraries","QML_lib"))
import Evo as evo
import DataBase 
import QMD
import QML
import ModelGeneration
import BayesF
import matplotlib.pyplot as plt

global paulis_list
paulis_list = {'i' : np.eye(2), 'x' : evo.sigmax(), 'y' : evo.sigmay(), 'z' : evo.sigmaz()}

warnings.filterwarnings("ignore", message='Negative weights occured', category=RuntimeWarning)



class NewQMDClass():
    #TODO: rename as ModelsDevelopmentClass when finished
    def __init__(self,
                 initial_op_list,
                 true_operator='x',
                 maxmodnum=3, 
                 max_num_qubits=4, 
                 gaussian=True,
                 max_num_layers = 10,
                 max_num_branches = 20, 
                 use_exp_custom = True
                ):
#    def __init__(self, initial_op_list, true_op_list, true_param_list):
        
        trueOp = DataBase.operator(true_operator)
        self.TrueOpName = true_operator
        self.TrueOpDim = trueOp.num_qubits
        self.InitialOpList = initial_op_list
        self.TrueOpList = trueOp.constituents_operators
#        self.TrueParamsList = [random.random() for i in self.TrueOpList] # TODO: actual true params?
        # todo set true parmams properly
        self.TrueParamsList = [0.75 for i in self.TrueOpList] # TODO: actual true params?
        #self.TrueHam = evo.getH(self.TrueParamsList, self.TrueOpList)
        self.TrueHam = np.tensordot(self.TrueParamsList, self.TrueOpList, axes=1)
        self.MaxModNum = maxmodnum #TODO: necessary?
        self.gaussian = gaussian
        self.NumModels = len(initial_op_list)
        self.NumParticles = 1000
        self.MaxQubitNumber = max_num_qubits
        self.HighestQubitNumber = int(0)
        self.MaxBranchID = max_num_branches
        self.HighestBranchID = 0
        self.MaxLayerNumber = max_num_layers
        self.BranchChampions = {}
        self.LayerChampions = {}
        self.BayesFactorsByBranch ={}
        self.BranchRankings = {}
        self.BranchBayesComputed = {}
        self.InterBranchChampions = {}
        self.GlobalEpoch = 0 
        self.UseExpCustom = use_exp_custom
        
#        for i in range(self.MaxBranchID+1):
#            self.BranchChampions[i] = 0
#        for i in range(self.MaxLayerNumber+1):
#            self.LayerChampions[i] = 0
        
        print("\nQMD has true operator: ", true_operator)
        print("QMD has true params : ", self.TrueParamsList, "\n")

        # Initialise database and lists.
        self.initiateDB()
        
    def initiateDB(self):
        
        ## TODO: Models should be initialised with appropriate TrueOp dimension -- see getListTrueOpByDimension function
        self.db, self.legacy_db, self.model_lists = \
            DataBase.launch_db(
                true_op_name = self.TrueOpName,
                gen_list = self.InitialOpList,
                true_ops = self.TrueOpList,
                true_params = self.TrueParamsList,
                redimensionalise = True,
                use_exp_custom = self.UseExpCustom,
            )
    def addModel(self, model, treeID=0):
        self.NumModels += 1
        tryAddModel = DataBase.add_model(
            model_name = model,
            running_database = self.db,
            num_particles = self.NumParticles, 
            true_op_name = self.TrueOpName,
            model_lists = self.model_lists,
            true_ops = self.TrueOpList,
            true_params = self.TrueParamsList,
            treeID = treeID,
            use_exp_custom = self.UseExpCustom,
            modelID = self.NumModels,
            redimensionalise = True,
        )
        if tryAddModel == True: 
            if DataBase.get_num_qubits(model) > self.HighestQubitNumber:
                self.HighestQubitNumber = DataBase.get_num_qubits(model)
        else: 
            self.NumModels-=int(1)

    def newBranch(self, model_list):
        self.HighestBranchID += 1
        branchID = self.HighestBranchID
        self.BranchBayesComputed[float(branchID)] = False
        for model in model_list:
            self.addModel(model, treeID=branchID)
    
    def printState(self):
        print("Branch champions: \n", self.BranchChampions)
        print("InterBranch champions: \n", self.InterBranchChampions)
        print("Branch Rankings: \n", self.BranchRankings)
        #print("Layer Champions: \n", self.LayerChampions)
            
            
    def getModelInstance(self, name):
        try: 
            instance = DataBase.get_qml_instance(self.db, name)
            return instance
        except: 
            if name in list(self.legacy_db['<Name>']):
                print("Operator in legacy databse - retired. ")
            else: 
                print("Model not found.")
    def getOperatorInstance(self, name):
        try: 
            return DataBase.get_operator_instance(self.db, name)
        except:
            if name in list(self.legacy_db['<Name>']):
                print("Operator in legacy databse - retired. ")
            else: 
                print("Operator not found.")

    def getModelDBIndex(self, name):
        return DataBase.get_location(self.db, name)

    def getModelInstanceFromID(self, model_id):
        return DataBase.model_instance_from_id(self.db, model_id)    
    
    def killModel(self, name):
        if name not in list(self.db['<Name>']):
            print("Cannot remove ", name, "; not in ", list(self.db["<Name>"]))
        else:
            print("Killing model", name)
            # Add to legacy_db
            DataBase.move_to_legacy(self.db, self.legacy_db, name)
            model_instance = self.getModelInstance(name)
            operator_instance = self.getOperatorInstance(name)
            # Remove from self.db
            self.db = DataBase.remove_model(self.db, name)
            del model_instance
            del operator_instance
    
            #TODO: plot?

    def runIQLE(self, model, num_exp=50):
        model_exists=False
        if model in list(self.db['<Name>']):
            model_exists = True
        elif model in list(self.legacy_db['<Name>']):
            print("Model ", model, " previously considered and retired.")
        
        has_model_finished = self.pullField(name=model, field='Completed')
        
        if model_exists==True and has_model_finished==False : 
            model_instance = self.getModelInstance(model)
            print("\nRunning IQLE for model: ", model)
            model_instance.UpdateModel(num_exp)
            self.updateModelRecord(name=model, field='Completed', new_value=True)
            #model_instance.BayesOnModelsWithinTrees
        else: 
            print("Model ", model ,"does not exist")

    def runAllActiveModelsIQLE(self, num_exp):
        active_models = self.db.loc[self.db['Status']=='Active']['<Name>']

        for model in active_models:
            self.runIQLE(model=model, num_exp=num_exp)
        self.GlobalEpoch += num_exp
            
        
    def updateModelRecord(self, field, name=None, model_id=None, new_value=None, increment=None):
        DataBase.update_field(
            db=self.db, 
            name=name,
            model_id=model_id,
            field=field,
            new_value=new_value,
            increment=increment
        )
    def pullField(self, name, field):
        return DataBase.pull_field(self.db, name, field)

    def statusChangeBranch(self, branchID, new_status='Saturated'):
        self.db.loc[ self.db['TreeID']==branchID , 'Status'] = new_status

    def statusChangeModel(self, model_name, new_status='Saturated'):
        self.db.loc[ self.db['<Name>']==model_name , 'Status'] = new_status
        
    def getListTrueOpByDimension(self):
        self.TrueOpListByDim = {}
        self.TrueParamByDim = {}
        for dim in range(1, 1+self.MaxDimension):
            new_op = ModelGeneration.identity_interact(subsystem=self.TrueOpName, num_qubits=dim, return_operator=True)
            self.TrueOpListByDim[dim] = new_op.constituents_operators
        for i in range(1, self.TrueOpDim+1):
            self.TrueParamByDim[i] = self.TrueParamsList
        for i in range(self.TrueOpDim+1, self.MaxDimension):
            self.TrueParamByDim[i] = [self.TrueParamsList[0]]

    def compareModels(self, log_comparison_high=50.0, num_times_to_use = 'all', model_a_id = None, model_b_id =None, model_a = None, model_b = None, name_a=None, name_b=None):
        # Either pass in name_a and name_b OR model_a and model_b
        if model_a is None and model_b is None:
            if model_a_id is not None and model_b_id is not None: 
                model_a = self.getModelInstanceFromID(model_a_id)
                model_b = self.getModelInstanceFromID(model_b_id)
            else: # if only names were passed 
                model_a = self.getModelInstance(name_a)
                model_b = self.getModelInstance(name_b)
        if model_a ==  model_b:
            print("Same models, don't need to compare.")
            return "Same Models"

        log_comparison_low = 1/log_comparison_high
        
        if num_times_to_use == 'all':
            times_a = model_a.TrackTime
        elif len(model_a.TrackTime) < num_times_to_use:
            times_a = model_a.TrackTime
        else: 
            times_a = model_a.TrackTime[num_times_to_use:]
        
        if num_times_to_use=='all':
            times_b = model_b.TrackTime
        elif len(model_b.TrackTime) < num_times_to_use:
            times_b = model_b.TrackTime
        else: 
            times_b = model_b.TrackTime[num_times_to_use:]
        gen_a = model_a.GenSimModel
        gen_b = model_b.GenSimModel

        times = times_a + times_b
        exps_a = get_exps(model_a, gen_a, times)
        exps_b = get_exps(model_b, gen_b, times)

        log_l_a =  get_log_likelihood(model_a, gen_a, exps_a)
        log_l_b =  get_log_likelihood(model_b, gen_b, exps_b)

        bayes_factor = np.exp(log_l_a - log_l_b)

        print("bayes_factor of log likelihoods between ", model_a.Name, " and ", model_b.Name, " = ", bayes_factor)
        if bayes_factor > log_comparison_high: 
            print("Point to ", model_a.Name)
            return "a"
        elif bayes_factor < log_comparison_low: 
            print("Point to ", model_b.Name)
            return "b"
        else:
            print("No real winner")  
        # todo: Add bayes_factor with mod_id's to QML class

            
    def compareModelsWithinBranch(self, treeID):
        active_models_in_tree = DataBase.active_model_ids_by_tree_id(self.db, treeID)
        
        models_points = {}
        for model_id in active_models_in_tree:
            models_points[model_id] = 0
        
        for i in range(len(active_models_in_tree)):
            mod1 = active_models_in_tree[i]
            for j in range(i, len(active_models_in_tree)): 
                mod2 = active_models_in_tree[j]
                res = self.compareModels(model_a_id = mod1, model_b_id=mod2)
                if res == "a":
                    models_points[mod1] += 1
                elif res == "b":
                    models_points[mod2] += 1
                    # todo if more than one model has max points
                    
        max_points = max(models_points.values())
        max_points_branches = [key for key, val in models_points.items() if val==max_points]
        if len(max_points_branches) > 1: 
            # todo: recompare. Fnc: compareListOfModels (rather than branch based)
            champ_id = self.compareModelList(max_points_branches, bayes_threshold=1, models_points_dict=models_points)
        else: 
            champ_id = max(models_points, key=models_points.get)
        champ_name = DataBase.model_name_from_id(self.db, champ_id)
        
        #todo list of ranked models by branch
        
        self.BranchChampions[int(treeID)] = champ_id
        for model_id in active_models_in_tree:
            self.updateModelRecord(model_id=model_id, field='Status', new_value='Deactivated')
        self.updateModelRecord(name=DataBase.model_name_from_id(self.db, champ_id), field='Status', new_value='Active')

# sorted_keys = sorted(my_dict, key=my_dict.get, reverse=True)
        ranked_model_list = sorted_keys = sorted(models_points, key=models_points.get, reverse=True)
        print("Branch: ", treeID)
        print("List : ", ranked_model_list)
        print("Models_points dict : ", models_points)

        print("TreeID=", treeID, " has type ", type(treeID))
        #print("branch computed: ", self.BranchBayesComputed[int(float(treeID))] )
        #if self.BranchBayesComputed[float(treeID)] == False: # only update self.BranchRankings the first time branch is considered
        self.BranchRankings[treeID] = ranked_model_list
        #self.BranchBayesComputed[float(treeID)] = True
            
        print("Champion of tree ", treeID, " is ", champ_name)
        return models_points, champ_id

    
    def compareModelList(self, model_list, bayes_threshold = 50, models_points_dict=None):
        models_points = {}
        for mod in model_list:
            models_points[mod] = 0
        
        for i in range(len(model_list)):
            mod1 = model_list[i]
            for j in range(i, len(model_list)):
                mod2 = model_list[j]
                if mod1 != mod2:
                    res = self.compareModels(model_a_id=mod1, model_b_id=mod2, log_comparison_high=bayes_threshold)
                    if res == "a":
                        models_points[mod1] += 1
                        if models_points_dict is not None: 
                            models_points_dict[mod1]+=1
                    elif res == "b":
                        models_points[mod2]+=1
                        if models_points_dict is not None: 
                            models_points_dict[mod2]+=1

        max_points = max(models_points.values())
        max_points_branches = [key for key, val in models_points.items() if val==max_points]
        if len(max_points_branches) > 1: 
            # todo: recompare. Fnc: compareListOfModels (rather than branch based)
            print("No distinct champion, recomputing bayes factors between : ", max_points_branches)
            champ_id = self.compareModelList(max_points_branches, bayes_threshold=1)
        else: 
            champ_id = max(models_points, key=models_points.get)
        champ_name = DataBase.model_name_from_id(self.db, champ_id)

        
        return champ_id
    
    def interBranchChampion(self, branch_list=[], global_champion=False):
        all_branches = self.db['TreeID'].unique()
        if global_champion == True: 
            trees = all_branches
        else: 
            trees = branch_list
        
        num_branches = len(trees)
        points_by_branches = [None] * num_branches
        champions_of_branches = [None] * num_branches

        for i in range(num_branches):
            treeID = trees[i]
            if treeID not in all_branches:
                print("Tree ID : ", treeID)
                warnings.warn("Tree not in database.")
                return False
            points_by_branches[i], champions_of_branches[i] = qmd.compareModelsWithinBranch(treeID)

        branch_champions_points = {}
        for c in champions_of_branches: 
            branch_champions_points[c] = 0

        for i in range(num_branches):
            mod1 = champions_of_branches[i]
            for j in range(i, num_branches):
                mod2 = champions_of_branches[j]
                if mod1!=mod2:
                    res = self.compareModels(model_a_id=mod1, model_b_id=mod2, log_comparison_high=20.0)
                    if res == "a":
                        branch_champions_points[mod1] += 1
                    elif res == "b":
                        branch_champions_points[mod2] += 1
        self.ranked_champions = sorted(branch_champions_points, reverse=True)
        
        max_points = max(branch_champions_points.values())
        max_points_branches = [key for key, val in branch_champions_points.items() if val==max_points]
        if len(max_points_branches) > 1: 
            # todo: recompare. Fnc: compareListOfModels (rather than branch based)
            print("No distinct champion, recomputing bayes factors between : ", max_points_branches)
            champ_id = self.compareModelList(max_points_branches, bayes_threshold=1, models_points_dict=branch_champions_points)
        else: 
            champ_id = max(branch_champions_points, key=branch_champions_points.get)
        champ_name = DataBase.model_name_from_id(self.db, champ_id)
        
        branch_champ_names = [DataBase.model_name_from_id(self.db, mod_id) for mod_id in champions_of_branches]
        self.statusChangeModel(champ_name, new_status = 'Active')
        
        interBranchChampListID = len(self.InterBranchChampions)
        self.InterBranchChampions[interBranchChampListID] = [trees, champ_id]
        print("Champion of branches ", trees, " is ",  champ_name)
        return champ_name, branch_champ_names
    
    def globalChampionCalculation(self):
        trees = self.db['TreeID'].unique()
        
        num_trees = len(trees)
        self.points_by_trees = [None] * num_trees
        self.champions_of_trees = [None] * num_trees

        for i in range(num_trees):
            treeID = trees[i]
            self.points_by_trees[i], self.champions_of_trees[i] = qmd.compareModelsWithinBranch(treeID)

        self.champions_points = {}
        for c in self.champions_of_trees: 
            self.champions_points[c] = 0

        for i in range(num_trees):
            mod1 = self.champions_of_trees[i]
            for j in range(i, num_trees):
                mod2 = self.champions_of_trees[j]
                if mod1!=mod2:
                    res = self.compareModels(model_a_id=mod1, model_b_id=mod2, log_comparison_high=10.0)
                    if res == "a":
                        self.champions_points[mod1] += 1
                    elif res == "b":
                        self.champions_points[mod2]+=1
        self.ranked_champions = sorted(self.champions_points, reverse=True)
        champ_id = max(self.champions_points, key=self.champions_points.get)
        champ_name = DataBase.model_name_from_id(self.db, champ_id)
        print("Champion of Champions is",  champ_name)
        
        
    def spawn(self, 
              branch_list = None, 
              num_models_to_consider=1, 
              absolute_champion=False, 
              all_branches=False
             ):

        if all_branches or branch_list is None: 
            global_champion = True
            
        overall_champ, branch_champions = self.interBranchChampion(branch_list=branch_list, global_champion=global_champion)

        print("Overall champ : ", overall_champ)
        if absolute_champion:
            print("Only using absolute champion")
            new_models = ModelGeneration.new_model_list(model_list=[overall_champ], generator='simple_ising',options=['x', 'y'])
        else: 
            print("Using branch champions list")
            print("branch champions : ", branch_champions)
            new_models = ModelGeneration.new_model_list(model_list=branch_champions, generator='simple_ising', options=['x', 'y'])
        
        print("New models to add to new branch : ", new_models)
        qmd.newBranch(model_list=new_models) 
        
        #todo probailistically append model_list with suboptimal model in any of the branches in branch_list

    def runQMD(self, num_exp = 20, max_branches= None, max_num_qubits = None):
        if max_branches is None:
            max_branches = self.MaxBranchID

        if max_num_qubits is None:
            max_num_qubits = self.MaxQubitNumber
            
        while self.HighestQubitNumber < max_num_qubits: 
            self.runAllActiveModelsIQLE(num_exp=num_exp)
            self.spawn()
            if self.HighestBranchID > max_branches:
                break
            
        self.runAllActiveModelsIQLE(num_exp=num_exp)
        final_winner, final_branch_winners = self.interBranchChampion(global_champion=True)
        print("Final winner = ", final_winner)
        
def get_exps(model, gen, times):

    exps = np.empty(len(times), dtype=gen.expparams_dtype)
    exps['t'] = times

    for i in range(1, len(gen.expparams_dtype)):
        col_name = 'w_'+str(i)
        exps[col_name] = model.FinalParams[i-1,0] ## TODO: should be model.NewEval[i-1]???
    return exps

def get_log_likelihood(model, gen, exps):
    import copy
    updater = copy.deepcopy(model.Updater)
    data = gen.simulate_experiment(model.SimParams, exps)[0][0]
    updater.batch_update(data, exps, resample_interval=100)
    log_likelihood = np.sum(updater.log_total_likelihood)
    del updater
    return log_likelihood
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)
# /usr/local/lib/python2.7/dist-packages/qinfer/parallel.py:52: UserWarning: Could not import IPython parallel. Parallelization support will be disabled.
#   "Could not import IPython parallel. "

# %%
import random
num_exp = 50

#max_dim=2
#dims = range(1,max_dim+1)
#num_qubits=random.choice(dims)

true_op = 'xTx'
generators = ['x', 'y']

qmd = NewQMDClass(initial_op_list=generators, true_operator=true_op)
# qmd.runQMD(num_exp=num_exp, max_branches=2, max_num_qubits=1)

for use_exp in [True, False]:
    print("\n\n\n\n USE EXP HAM: ", use_exp)
    for i in range(15):
        print("\n\n\n i= ", i)
        qmd = NewQMDClass(initial_op_list=generators, true_operator=true_op, use_exp_custom=use_exp)
        qmd.runIQLE(model='x', num_exp=num_exp)
        qmd.runIQLE(model='y', num_exp=num_exp)

        for j in range(100):
            print("\n\n j= ", j)
            qmd.compareModels(model_a_id=0, model_b_id=1)
#### Below: results with exp_ham turned on
# Out:
# QMD has true operator:  xTx
# QMD has true params :  [0.75]
#
# Redimensionalising
# Before dimensionalising name. Name =  x true_dim =  2
# Model  x  not previously considered -- adding.
# Initialization Ready
# Redimensionalising
# Before dimensionalising name. Name =  y true_dim =  2
# Model  y  not previously considered -- adding.
# Initialization Ready
#
#
#
#
#  USE EXP HAM:  True
#
#
#
#  i=  0
#
# QMD has true operator:  xTx
# QMD has true params :  [0.75]
#
# Redimensionalising
# Before dimensionalising name. Name =  x true_dim =  2
# Model  x  not previously considered -- adding.
# Initialization Ready
# Redimensionalising
# Before dimensionalising name. Name =  y true_dim =  2
# Model  y  not previously considered -- adding.
# Initialization Ready
#
# Running IQLE for model:  x
# Initial time selected > 0.637311928609
# Final time selected > 2.4764217497
# Final Parameters mean and stdev:[ 0.29658912  0.28583024]
#
# Running IQLE for model:  y
# Initial time selected > 1.37544940721
# Final time selected > 6.69673264852
# Final Parameters mean and stdev:[ 0.85297783  0.43704222]
#
#
#  j=  0
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.20946045167e-08
# Point to  yTi
#
#
#  j=  1
# bayes_factor of log likelihoods between  xTi  and  yTi  =  8.29280466106e-16
# Point to  yTi
#
#
#  j=  2
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.73381381761e-11
# Point to  yTi
#
#
#  j=  3
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.45347820607e-08
# Point to  yTi
#
#
#  j=  4
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.79692778415e-08
# Point to  yTi
#
#
#  j=  5
# bayes_factor of log likelihoods between  xTi  and  yTi  =  321.49056635
# Point to  xTi
#
#
#  j=  6
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.10662364509e-05
# Point to  yTi
#
#
#  j=  7
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.33039725493
# No real winner
#
#
#  j=  8
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.581233476035
# No real winner
#
#
#  j=  9
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0753736644578
# No real winner
#
#
#  j=  10
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.43108110951e-10
# Point to  yTi
#
#
#  j=  11
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.90961078917e-11
# Point to  yTi
#
#
#  j=  12
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0128233231779
# Point to  yTi
#
#
#  j=  13
# bayes_factor of log likelihoods between  xTi  and  yTi  =  8.6322718345e-07
# Point to  yTi
#
#
#  j=  14
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0850749112001
# No real winner
#
#
#  j=  15
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.48910026559e-05
# Point to  yTi
#
#
#  j=  16
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.9112470251e-15
# Point to  yTi
#
#
#  j=  17
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6.02434027616e-08
# Point to  yTi
#
#
#  j=  18
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.50975307296e-09
# Point to  yTi
#
#
#  j=  19
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.85474936114e-08
# Point to  yTi
#
#
#  j=  20
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000478474016701
# Point to  yTi
#
#
#  j=  21
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.08777232399e-10
# Point to  yTi
#
#
#  j=  22
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6.13748444386e-09
# Point to  yTi
#
#
#  j=  23
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000630534052324
# Point to  yTi
#
#
#  j=  24
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.93352679122e-08
# Point to  yTi
#
#
#  j=  25
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0599044186317
# No real winner
#
#
#  j=  26
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.14228988889e-12
# Point to  yTi
#
#
#  j=  27
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.35168113873e-07
# Point to  yTi
#
#
#  j=  28
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.84173222363e-07
# Point to  yTi
#
#
#  j=  29
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.04265297877e-06
# Point to  yTi
#
#
#  j=  30
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000247706097769
# Point to  yTi
#
#
#  j=  31
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0491554144819
# No real winner
#
#
#  j=  32
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.35299021035e-05
# Point to  yTi
#
#
#  j=  33
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.38782830888e-10
# Point to  yTi
#
#
#  j=  34
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00125129884357
# Point to  yTi
#
#
#  j=  35
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3343360.0356
# Point to  xTi
#
#
#  j=  36
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000230582090741
# Point to  yTi
#
#
#  j=  37
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.0015759046e-08
# Point to  yTi
#
#
#  j=  38
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.689511790179
# No real winner
#
#
#  j=  39
# bayes_factor of log likelihoods between  xTi  and  yTi  =  9.45487930366e-06
# Point to  yTi
#
#
#  j=  40
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.98778617169e-10
# Point to  yTi
#
#
#  j=  41
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.4362748695e-09
# Point to  yTi
#
#
#  j=  42
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.95965798751e-08
# Point to  yTi
#
#
#  j=  43
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6.78383718686e-06
# Point to  yTi
#
#
#  j=  44
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00381412726412
# Point to  yTi
#
#
#  j=  45
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.044897709743
# No real winner
#
#
#  j=  46
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.82212713923e-10
# Point to  yTi
#
#
#  j=  47
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.22853263274e-13
# Point to  yTi
#
#
#  j=  48
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00164810355473
# Point to  yTi
#
#
#  j=  49
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00487814854381
# Point to  yTi
#
#
#  j=  50
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.54450091297
# No real winner
#
#
#  j=  51
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00317662327196
# Point to  yTi
#
#
#  j=  52
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.32917616295e-05
# Point to  yTi
#
#
#  j=  53
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.40440069416e-05
# Point to  yTi
#
#
#  j=  54
# bayes_factor of log likelihoods between  xTi  and  yTi  =  8.03767355411e-06
# Point to  yTi
#
#
#  j=  55
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.84251630755e-09
# Point to  yTi
#
#
#  j=  56
# bayes_factor of log likelihoods between  xTi  and  yTi  =  7.0055486084e-06
# Point to  yTi
#
#
#  j=  57
# bayes_factor of log likelihoods between  xTi  and  yTi  =  27.9469280386
# No real winner
#
#
#  j=  58
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.0073213396e-06
# Point to  yTi
#
#
#  j=  59
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.04765875484e-05
# Point to  yTi
#
#
#  j=  60
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.7311319437e-08
# Point to  yTi
#
#
#  j=  61
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.27102723982e-13
# Point to  yTi
#
#
#  j=  62
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6.38103119404e-07
# Point to  yTi
#
#
#  j=  63
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.20332601407e-08
# Point to  yTi
#
#
#  j=  64
# bayes_factor of log likelihoods between  xTi  and  yTi  =  30.3412269625
# No real winner
#
#
#  j=  65
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0441622118651
# No real winner
#
#
#  j=  66
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.78399053302e-07
# Point to  yTi
#
#
#  j=  67
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.131775213614
# No real winner
#
#
#  j=  68
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.07874001548e-08
# Point to  yTi
#
#
#  j=  69
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0297521912555
# No real winner
#
#
#  j=  70
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.43127334799e-09
# Point to  yTi
#
#
#  j=  71
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.07676323304e-08
# Point to  yTi
#
#
#  j=  72
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000105160329213
# Point to  yTi
#
#
#  j=  73
# bayes_factor of log likelihoods between  xTi  and  yTi  =  9.84412892399e-07
# Point to  yTi
#
#
#  j=  74
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.49623576936e-07
# Point to  yTi
#
#
#  j=  75
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.28481200995e-06
# Point to  yTi
#
#
#  j=  76
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.90155636914e-11
# Point to  yTi
#
#
#  j=  77
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.79339234233e-09
# Point to  yTi
#
#
#  j=  78
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.166280922e-08
# Point to  yTi
#
#
#  j=  79
# bayes_factor of log likelihoods between  xTi  and  yTi  =  680.826985212
# Point to  xTi
#
#
#  j=  80
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1561.88104735
# Point to  xTi
#
#
#  j=  81
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.29762011279e-06
# Point to  yTi
#
#
#  j=  82
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000446403802151
# Point to  yTi
#
#
#  j=  83
# bayes_factor of log likelihoods between  xTi  and  yTi  =  9.61198208197e-09
# Point to  yTi
#
#
#  j=  84
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.95601389902e-07
# Point to  yTi
#
#
#  j=  85
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.05311234946e-08
# Point to  yTi
#
#
#  j=  86
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.59810375574e-05
# Point to  yTi
#
#
#  j=  87
# bayes_factor of log likelihoods between  xTi  and  yTi  =  7.81136060145e-08
# Point to  yTi
#
#
#  j=  88
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.06408123091e-06
# Point to  yTi
#
#
#  j=  89
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6.7701506587
# No real winner
#
#
#  j=  90
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00178572587923
# Point to  yTi
#
#
#  j=  91
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.1010093086e-09
# Point to  yTi
#
#
#  j=  92
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.57476976582e-09
# Point to  yTi
#
#
#  j=  93
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.4835740042e-07
# Point to  yTi
#
#
#  j=  94
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00369772201954
# Point to  yTi
#
#
#  j=  95
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00216556918608
# Point to  yTi
#
#
#  j=  96
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.208119642279
# No real winner
#
#
#  j=  97
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00153688750745
# Point to  yTi
#
#
#  j=  98
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.58657789405e-05
# Point to  yTi
#
#
#  j=  99
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00168370572654
# Point to  yTi
#
#
#
#  i=  1
#
# QMD has true operator:  xTx
# QMD has true params :  [0.75]
#
# Redimensionalising
# Before dimensionalising name. Name =  x true_dim =  2
# Model  x  not previously considered -- adding.
# Initialization Ready
# Redimensionalising
# Before dimensionalising name. Name =  y true_dim =  2
# Model  y  not previously considered -- adding.
# Initialization Ready
#
# Running IQLE for model:  x
# Initial time selected > 11.6133722939
# Final time selected > 2.09071272018
# Final Parameters mean and stdev:[ 0.77421809  0.20861118]
#
# Running IQLE for model:  y
# Initial time selected > 1.21354490546
# Final time selected > 3.87223266087
# Final Parameters mean and stdev:[-0.43979196  0.44432989]
#
#
#  j=  0
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.9295524878e-05
# Point to  yTi
#
#
#  j=  1
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.31088810656e-10
# Point to  yTi
#
#
#  j=  2
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.52998431373e-07
# Point to  yTi
#
#
#  j=  3
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.72776411922e-09
# Point to  yTi
#
#
#  j=  4
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.28483468011e-07
# Point to  yTi
#
#
#  j=  5
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000119689605877
# Point to  yTi
#
#
#  j=  6
# bayes_factor of log likelihoods between  xTi  and  yTi  =  9.37394860727e-07
# Point to  yTi
#
#
#  j=  7
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0104204573667
# Point to  yTi
#
#
#  j=  8
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0016723711214
# Point to  yTi
#
#
#  j=  9
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1090.81657959
# Point to  xTi
#
#
#  j=  10
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.09036353003e-10
# Point to  yTi
#
#
#  j=  11
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00246543323942
# Point to  yTi
#
#
#  j=  12
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.86863231187e-07
# Point to  yTi
#
#
#  j=  13
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.39279314124e-09
# Point to  yTi
#
#
#  j=  14
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.74257048321e-06
# Point to  yTi
#
#
#  j=  15
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0230691330208
# No real winner
#
#
#  j=  16
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.08390119207e-06
# Point to  yTi
#
#
#  j=  17
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.08733311377e-09
# Point to  yTi
#
#
#  j=  18
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.37052173763e-06
# Point to  yTi
#
#
#  j=  19
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.78358334477e-06
# Point to  yTi
#
#
#  j=  20
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.68875314282e-08
# Point to  yTi
#
#
#  j=  21
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.72548746758e-11
# Point to  yTi
#
#
#  j=  22
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.20776441636e-07
# Point to  yTi
#
#
#  j=  23
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0274916544084
# No real winner
#
#
#  j=  24
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6.05475558311e-07
# Point to  yTi
#
#
#  j=  25
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.27219931306e-07
# Point to  yTi
#
#
#  j=  26
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.49726098876e-05
# Point to  yTi
#
#
#  j=  27
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.79783704967e-09
# Point to  yTi
#
#
#  j=  28
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6.14008430812e-13
# Point to  yTi
#
#
#  j=  29
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.12318185974e-05
# Point to  yTi
#
#
#  j=  30
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00180617334945
# Point to  yTi
#
#
#  j=  31
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.68311074114e-07
# Point to  yTi
#
#
#  j=  32
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00044158033411
# Point to  yTi
#
#
#  j=  33
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.26362516419e-08
# Point to  yTi
#
#
#  j=  34
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0142772500277
# Point to  yTi
#
#
#  j=  35
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6.33012185255e-07
# Point to  yTi
#
#
#  j=  36
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.14413202122e-13
# Point to  yTi
#
#
#  j=  37
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.19832875446
# No real winner
#
#
#  j=  38
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00038624045644
# Point to  yTi
#
#
#  j=  39
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.68650945352e-05
# Point to  yTi
#
#
#  j=  40
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.238671210194
# No real winner
#
#
#  j=  41
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00387107308566
# Point to  yTi
#
#
#  j=  42
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.06324818415e-06
# Point to  yTi
#
#
#  j=  43
# bayes_factor of log likelihoods between  xTi  and  yTi  =  7.32090316209e-13
# Point to  yTi
#
#
#  j=  44
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.80530907915e-11
# Point to  yTi
#
#
#  j=  45
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000133148618984
# Point to  yTi
#
#
#  j=  46
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00580240582734
# Point to  yTi
#
#
#  j=  47
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00054993457626
# Point to  yTi
#
#
#  j=  48
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.11503495132e-06
# Point to  yTi
#
#
#  j=  49
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.03362092276e-05
# Point to  yTi
#
#
#  j=  50
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000163354589827
# Point to  yTi
#
#
#  j=  51
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6.84396151947e-06
# Point to  yTi
#
#
#  j=  52
# bayes_factor of log likelihoods between  xTi  and  yTi  =  7.65603572119e-05
# Point to  yTi
#
#
#  j=  53
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00114741106169
# Point to  yTi
#
#
#  j=  54
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.95576788251e-08
# Point to  yTi
#
#
#  j=  55
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00977598497483
# Point to  yTi
#
#
#  j=  56
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.36922279597e-06
# Point to  yTi
#
#
#  j=  57
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.11265786368e-06
# Point to  yTi
#
#
#  j=  58
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.02866815644e-09
# Point to  yTi
#
#
#  j=  59
# bayes_factor of log likelihoods between  xTi  and  yTi  =  9.30866235574e-09
# Point to  yTi
#
#
#  j=  60
# bayes_factor of log likelihoods between  xTi  and  yTi  =  17.4475682616
# No real winner
#
#
#  j=  61
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.1795510434e-05
# Point to  yTi
#
#
#  j=  62
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.9134901976e-08
# Point to  yTi
#
#
#  j=  63
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.54641837839e-05
# Point to  yTi
#
#
#  j=  64
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.49086284926e-07
# Point to  yTi
#
#
#  j=  65
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000344923215609
# Point to  yTi
#
#
#  j=  66
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.89682625098e-08
# Point to  yTi
#
#
#  j=  67
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00102412777936
# Point to  yTi
#
#
#  j=  68
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00259961278064
# Point to  yTi
#
#
#  j=  69
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00307484671533
# Point to  yTi
#
#
#  j=  70
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000139257761374
# Point to  yTi
#
#
#  j=  71
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.00804875839e-05
# Point to  yTi
#
#
#  j=  72
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00531272143465
# Point to  yTi
#
#
#  j=  73
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.85467526264e-10
# Point to  yTi
#
#
#  j=  74
# bayes_factor of log likelihoods between  xTi  and  yTi  =  7.44765854136e-06
# Point to  yTi
#
#
#  j=  75
# bayes_factor of log likelihoods between  xTi  and  yTi  =  8.18085611052e-08
# Point to  yTi
#
#
#  j=  76
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.28677053806e-05
# Point to  yTi
#
#
#  j=  77
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000353389003544
# Point to  yTi
#
#
#  j=  78
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.06934747853e-07
# Point to  yTi
#
#
#  j=  79
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.74198786915e-05
# Point to  yTi
#
#
#  j=  80
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00154568339839
# Point to  yTi
#
#
#  j=  81
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.03517525213e-09
# Point to  yTi
#
#
#  j=  82
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.77134729892e-07
# Point to  yTi
#
#
#  j=  83
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.43314944932e-05
# Point to  yTi
#
#
#  j=  84
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00546857431423
# Point to  yTi
#
#
#  j=  85
# bayes_factor of log likelihoods between  xTi  and  yTi  =  9.88021319025e-07
# Point to  yTi
#
#
#  j=  86
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6.33629507042e-05
# Point to  yTi
#
#
#  j=  87
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.60089159148e-06
# Point to  yTi
#
#
#  j=  88
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.01094396107e-10
# Point to  yTi
#
#
#  j=  89
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000569690126556
# Point to  yTi
#
#
#  j=  90
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00023600285389
# Point to  yTi
#
#
#  j=  91
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.76622876692e-05
# Point to  yTi
#
#
#  j=  92
# bayes_factor of log likelihoods between  xTi  and  yTi  =  7.30069095765e-10
# Point to  yTi
#
#
#  j=  93
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.20850019788e-08
# Point to  yTi
#
#
#  j=  94
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.92775925031e-08
# Point to  yTi
#
#
#  j=  95
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.77565787432e-08
# Point to  yTi
#
#
#  j=  96
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.70117333691e-06
# Point to  yTi
#
#
#  j=  97
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00105499256752
# Point to  yTi
#
#
#  j=  98
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00116718370802
# Point to  yTi
#
#
#  j=  99
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000448494335386
# Point to  yTi
#
#
#
#  i=  2
#
# QMD has true operator:  xTx
# QMD has true params :  [0.75]
#
# Redimensionalising
# Before dimensionalising name. Name =  x true_dim =  2
# Model  x  not previously considered -- adding.
# Initialization Ready
# Redimensionalising
# Before dimensionalising name. Name =  y true_dim =  2
# Model  y  not previously considered -- adding.
# Initialization Ready
#
# Running IQLE for model:  x
# Initial time selected > 3.38034316504
# Final time selected > 1.36429746152
# Final Parameters mean and stdev:[-0.15379927  0.57152823]
#
# Running IQLE for model:  y
# Initial time selected > 0.55322188031
# Final time selected > 1.30216301791
# Final Parameters mean and stdev:[ 0.01096732  0.70363007]
#
#
#  j=  0
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.05782502957
# No real winner
#
#
#  j=  1
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.26415929857
# No real winner
#
#
#  j=  2
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.591429431316
# No real winner
#
#
#  j=  3
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.45365520522
# No real winner
#
#
#  j=  4
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000194132346907
# Point to  yTi
#
#
#  j=  5
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2061195.44855
# Point to  xTi
#
#
#  j=  6
# bayes_factor of log likelihoods between  xTi  and  yTi  =  98.2485697376
# Point to  xTi
#
#
#  j=  7
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2170.71461934
# Point to  xTi
#
#
#  j=  8
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.12676983773e-06
# Point to  yTi
#
#
#  j=  9
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.47655743291e-05
# Point to  yTi
#
#
#  j=  10
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0241113913956
# No real winner
#
#
#  j=  11
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.948767978006
# No real winner
#
#
#  j=  12
# bayes_factor of log likelihoods between  xTi  and  yTi  =  94072.2012285
# Point to  xTi
#
#
#  j=  13
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.35785604625
# No real winner
#
#
#  j=  14
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.91926477523
# No real winner
#
#
#  j=  15
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.35003210861e-06
# Point to  yTi
#
#
#  j=  16
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00110083232585
# Point to  yTi
#
#
#  j=  17
# bayes_factor of log likelihoods between  xTi  and  yTi  =  391549.450664
# Point to  xTi
#
#
#  j=  18
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.41355281095
# No real winner
#
#
#  j=  19
# bayes_factor of log likelihoods between  xTi  and  yTi  =  31215.2588806
# Point to  xTi
#
#
#  j=  20
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5048.44192447
# Point to  xTi
#
#
#  j=  21
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.706161656203
# No real winner
#
#
#  j=  22
# bayes_factor of log likelihoods between  xTi  and  yTi  =  267.921123379
# Point to  xTi
#
#
#  j=  23
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00853010022924
# Point to  yTi
#
#
#  j=  24
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00243037258668
# Point to  yTi
#
#
#  j=  25
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.83999659523e-06
# Point to  yTi
#
#
#  j=  26
# bayes_factor of log likelihoods between  xTi  and  yTi  =  74.8290028815
# Point to  xTi
#
#
#  j=  27
# bayes_factor of log likelihoods between  xTi  and  yTi  =  127.287696528
# Point to  xTi
#
#
#  j=  28
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.890069988852
# No real winner
#
#
#  j=  29
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.266851499749
# No real winner
#
#
#  j=  30
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.40806922648
# No real winner
#
#
#  j=  31
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.16813510199e-05
# Point to  yTi
#
#
#  j=  32
# bayes_factor of log likelihoods between  xTi  and  yTi  =  12895.3916061
# Point to  xTi
#
#
#  j=  33
# bayes_factor of log likelihoods between  xTi  and  yTi  =  35022.1940017
# Point to  xTi
#
#
#  j=  34
# bayes_factor of log likelihoods between  xTi  and  yTi  =  79.0019034535
# Point to  xTi
#
#
#  j=  35
# bayes_factor of log likelihoods between  xTi  and  yTi  =  254.545831388
# Point to  xTi
#
#
#  j=  36
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1859.85268055
# Point to  xTi
#
#
#  j=  37
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000529537915385
# Point to  yTi
#
#
#  j=  38
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000722326373307
# Point to  yTi
#
#
#  j=  39
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.64862934158
# No real winner
#
#
#  j=  40
# bayes_factor of log likelihoods between  xTi  and  yTi  =  195.197615817
# Point to  xTi
#
#
#  j=  41
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2150.85641932
# Point to  xTi
#
#
#  j=  42
# bayes_factor of log likelihoods between  xTi  and  yTi  =  876.960992782
# Point to  xTi
#
#
#  j=  43
# bayes_factor of log likelihoods between  xTi  and  yTi  =  59.636277218
# Point to  xTi
#
#
#  j=  44
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000140745638324
# Point to  yTi
#
#
#  j=  45
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.14621964296e-07
# Point to  yTi
#
#
#  j=  46
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0177799808234
# Point to  yTi
#
#
#  j=  47
# bayes_factor of log likelihoods between  xTi  and  yTi  =  381.847727573
# Point to  xTi
#
#
#  j=  48
# bayes_factor of log likelihoods between  xTi  and  yTi  =  810.872523062
# Point to  xTi
#
#
#  j=  49
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000751542449142
# Point to  yTi
#
#
#  j=  50
# bayes_factor of log likelihoods between  xTi  and  yTi  =  32403.734569
# Point to  xTi
#
#
#  j=  51
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00278032035085
# Point to  yTi
#
#
#  j=  52
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.36964871825
# No real winner
#
#
#  j=  53
# bayes_factor of log likelihoods between  xTi  and  yTi  =  9.4846295901e-14
# Point to  yTi
#
#
#  j=  54
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0023798508783
# Point to  yTi
#
#
#  j=  55
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00788374802511
# Point to  yTi
#
#
#  j=  56
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5454.10495582
# Point to  xTi
#
#
#  j=  57
# bayes_factor of log likelihoods between  xTi  and  yTi  =  52.9033083205
# Point to  xTi
#
#
#  j=  58
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.115555305422
# No real winner
#
#
#  j=  59
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.39867450268e-05
# Point to  yTi
#
#
#  j=  60
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.203643849131
# No real winner
#
#
#  j=  61
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00107398491712
# Point to  yTi
#
#
#  j=  62
# bayes_factor of log likelihoods between  xTi  and  yTi  =  25.8187466989
# No real winner
#
#
#  j=  63
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2727.57912074
# Point to  xTi
#
#
#  j=  64
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0143516979272
# Point to  yTi
#
#
#  j=  65
# bayes_factor of log likelihoods between  xTi  and  yTi  =  15.476444354
# No real winner
#
#
#  j=  66
# bayes_factor of log likelihoods between  xTi  and  yTi  =  108.579935927
# Point to  xTi
#
#
#  j=  67
# bayes_factor of log likelihoods between  xTi  and  yTi  =  9.71927286234
# No real winner
#
#
#  j=  68
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.38691895164e-05
# Point to  yTi
#
#
#  j=  69
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.79491350142e-07
# Point to  yTi
#
#
#  j=  70
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.578978399859
# No real winner
#
#
#  j=  71
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00081104824897
# Point to  yTi
#
#
#  j=  72
# bayes_factor of log likelihoods between  xTi  and  yTi  =  70.3034931328
# Point to  xTi
#
#
#  j=  73
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.66396622175
# No real winner
#
#
#  j=  74
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0149998482848
# Point to  yTi
#
#
#  j=  75
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0219914176611
# No real winner
#
#
#  j=  76
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.50334123119
# No real winner
#
#
#  j=  77
# bayes_factor of log likelihoods between  xTi  and  yTi  =  7.05242126665
# No real winner
#
#
#  j=  78
# bayes_factor of log likelihoods between  xTi  and  yTi  =  848680.063609
# Point to  xTi
#
#
#  j=  79
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0203844249211
# No real winner
#
#
#  j=  80
# bayes_factor of log likelihoods between  xTi  and  yTi  =  59766.891536
# Point to  xTi
#
#
#  j=  81
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00495405256636
# Point to  yTi
#
#
#  j=  82
# bayes_factor of log likelihoods between  xTi  and  yTi  =  73.7474298332
# Point to  xTi
#
#
#  j=  83
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.66945805145
# No real winner
#
#
#  j=  84
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.149635574761
# No real winner
#
#
#  j=  85
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.5120534703
# No real winner
#
#
#  j=  86
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.512664823967
# No real winner
#
#
#  j=  87
# bayes_factor of log likelihoods between  xTi  and  yTi  =  16.0312711453
# No real winner
#
#
#  j=  88
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1062637857.33
# Point to  xTi
#
#
#  j=  89
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.321304594168
# No real winner
#
#
#  j=  90
# bayes_factor of log likelihoods between  xTi  and  yTi  =  7.20669926834e-06
# Point to  yTi
#
#
#  j=  91
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00297424096412
# Point to  yTi
#
#
#  j=  92
# bayes_factor of log likelihoods between  xTi  and  yTi  =  305.609055257
# Point to  xTi
#
#
#  j=  93
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5334.37775395
# Point to  xTi
#
#
#  j=  94
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.1327734537e-07
# Point to  yTi
#
#
#  j=  95
# bayes_factor of log likelihoods between  xTi  and  yTi  =  13017185.5603
# Point to  xTi
#
#
#  j=  96
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5113.30116266
# Point to  xTi
#
#
#  j=  97
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.104303126549
# No real winner
#
#
#  j=  98
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000105517929731
# Point to  yTi
#
#
#  j=  99
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00116607840106
# Point to  yTi
#
#
#
#  i=  3
#
# QMD has true operator:  xTx
# QMD has true params :  [0.75]
#
# Redimensionalising
# Before dimensionalising name. Name =  x true_dim =  2
# Model  x  not previously considered -- adding.
# Initialization Ready
# Redimensionalising
# Before dimensionalising name. Name =  y true_dim =  2
# Model  y  not previously considered -- adding.
# Initialization Ready
#
# Running IQLE for model:  x
# Initial time selected > 8.56806546154
# Final time selected > 1.9478308797
# Final Parameters mean and stdev:[ 0.51962864  0.3016847 ]
#
# Running IQLE for model:  y
# Initial time selected > 134.375990164
# Final time selected > 57.7818084561
# Final Parameters mean and stdev:[ 0.35048268  0.0605477 ]
#
#
#  j=  0
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.271800989605
# No real winner
#
#
#  j=  1
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000345615284235
# Point to  yTi
#
#
#  j=  2
# bayes_factor of log likelihoods between  xTi  and  yTi  =  13.7017317576
# No real winner
#
#
#  j=  3
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0772498595395
# No real winner
#
#
#  j=  4
# bayes_factor of log likelihoods between  xTi  and  yTi  =  60.4345371745
# Point to  xTi
#
#
#  j=  5
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4335.32314357
# Point to  xTi
#
#
#  j=  6
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.89520155609e-07
# Point to  yTi
#
#
#  j=  7
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.172439480799
# No real winner
#
#
#  j=  8
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.28085510651
# No real winner
#
#
#  j=  9
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.213706013491
# No real winner
#
#
#  j=  10
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00197460642809
# Point to  yTi
#
#
#  j=  11
# bayes_factor of log likelihoods between  xTi  and  yTi  =  675890.421127
# Point to  xTi
#
#
#  j=  12
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.902864939704
# No real winner
#
#
#  j=  13
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0869785373809
# No real winner
#
#
#  j=  14
# bayes_factor of log likelihoods between  xTi  and  yTi  =  463821.98156
# Point to  xTi
#
#
#  j=  15
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.170043103e-07
# Point to  yTi
#
#
#  j=  16
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.90055231161e-05
# Point to  yTi
#
#
#  j=  17
# bayes_factor of log likelihoods between  xTi  and  yTi  =  25015118.6918
# Point to  xTi
#
#
#  j=  18
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0293359182802
# No real winner
#
#
#  j=  19
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0879737637477
# No real winner
#
#
#  j=  20
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.305190331182
# No real winner
#
#
#  j=  21
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6173.80701254
# Point to  xTi
#
#
#  j=  22
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.46002962597
# No real winner
#
#
#  j=  23
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1848819.45339
# Point to  xTi
#
#
#  j=  24
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.039090073824
# No real winner
#
#
#  j=  25
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.142755165663
# No real winner
#
#
#  j=  26
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00110864478026
# Point to  yTi
#
#
#  j=  27
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000125190521943
# Point to  yTi
#
#
#  j=  28
# bayes_factor of log likelihoods between  xTi  and  yTi  =  547.901073001
# Point to  xTi
#
#
#  j=  29
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.126552579913
# No real winner
#
#
#  j=  30
# bayes_factor of log likelihoods between  xTi  and  yTi  =  7.25900133723e-06
# Point to  yTi
#
#
#  j=  31
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0097343093034
# Point to  yTi
#
#
#  j=  32
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1219.53887495
# Point to  xTi
#
#
#  j=  33
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.46258834484e-05
# Point to  yTi
#
#
#  j=  34
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.124393278574
# No real winner
#
#
#  j=  35
# bayes_factor of log likelihoods between  xTi  and  yTi  =  19.6214096087
# No real winner
#
#
#  j=  36
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00312920648421
# Point to  yTi
#
#
#  j=  37
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.564803200616
# No real winner
#
#
#  j=  38
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1363.53757014
# Point to  xTi
#
#
#  j=  39
# bayes_factor of log likelihoods between  xTi  and  yTi  =  20063.5935945
# Point to  xTi
#
#
#  j=  40
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0400520360196
# No real winner
#
#
#  j=  41
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00908215687235
# Point to  yTi
#
#
#  j=  42
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000248953494162
# Point to  yTi
#
#
#  j=  43
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.253471583363
# No real winner
#
#
#  j=  44
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.230004564906
# No real winner
#
#
#  j=  45
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0001932987258
# Point to  yTi
#
#
#  j=  46
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0406492649707
# No real winner
#
#
#  j=  47
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1341728.51809
# Point to  xTi
#
#
#  j=  48
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.190577520704
# No real winner
#
#
#  j=  49
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000886323111742
# Point to  yTi
#
#
#  j=  50
# bayes_factor of log likelihoods between  xTi  and  yTi  =  369126.145353
# Point to  xTi
#
#
#  j=  51
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.25447107582
# No real winner
#
#
#  j=  52
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.73368597473e-05
# Point to  yTi
#
#
#  j=  53
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.114613297349
# No real winner
#
#
#  j=  54
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000229919047224
# Point to  yTi
#
#
#  j=  55
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00290942121609
# Point to  yTi
#
#
#  j=  56
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00544211012944
# Point to  yTi
#
#
#  j=  57
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.789935228326
# No real winner
#
#
#  j=  58
# bayes_factor of log likelihoods between  xTi  and  yTi  =  321.576359359
# Point to  xTi
#
#
#  j=  59
# bayes_factor of log likelihoods between  xTi  and  yTi  =  918.564433724
# Point to  xTi
#
#
#  j=  60
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00547628225552
# Point to  yTi
#
#
#  j=  61
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.47293219406
# No real winner
#
#
#  j=  62
# bayes_factor of log likelihoods between  xTi  and  yTi  =  23.1640738402
# No real winner
#
#
#  j=  63
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00528282868614
# Point to  yTi
#
#
#  j=  64
# bayes_factor of log likelihoods between  xTi  and  yTi  =  15.9847700005
# No real winner
#
#
#  j=  65
# bayes_factor of log likelihoods between  xTi  and  yTi  =  19958.3246319
# Point to  xTi
#
#
#  j=  66
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00111105923753
# Point to  yTi
#
#
#  j=  67
# bayes_factor of log likelihoods between  xTi  and  yTi  =  114.589326495
# Point to  xTi
#
#
#  j=  68
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.42271797469
# No real winner
#
#
#  j=  69
# bayes_factor of log likelihoods between  xTi  and  yTi  =  7.1300568295
# No real winner
#
#
#  j=  70
# bayes_factor of log likelihoods between  xTi  and  yTi  =  9.19823675589
# No real winner
#
#
#  j=  71
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000381092786504
# Point to  yTi
#
#
#  j=  72
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00208288992583
# Point to  yTi
#
#
#  j=  73
# bayes_factor of log likelihoods between  xTi  and  yTi  =  7.63487899527e-07
# Point to  yTi
#
#
#  j=  74
# bayes_factor of log likelihoods between  xTi  and  yTi  =  41095.9901401
# Point to  xTi
#
#
#  j=  75
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00107845672341
# Point to  yTi
#
#
#  j=  76
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6701.05657122
# Point to  xTi
#
#
#  j=  77
# bayes_factor of log likelihoods between  xTi  and  yTi  =  56.6242148432
# Point to  xTi
#
#
#  j=  78
# bayes_factor of log likelihoods between  xTi  and  yTi  =  105.725580499
# Point to  xTi
#
#
#  j=  79
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.167088554663
# No real winner
#
#
#  j=  80
# bayes_factor of log likelihoods between  xTi  and  yTi  =  536.15176179
# Point to  xTi
#
#
#  j=  81
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0190755259771
# Point to  yTi
#
#
#  j=  82
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.46695199545
# No real winner
#
#
#  j=  83
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.59038673203
# No real winner
#
#
#  j=  84
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.241077331018
# No real winner
#
#
#  j=  85
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.51992128165
# No real winner
#
#
#  j=  86
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0539196575465
# No real winner
#
#
#  j=  87
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.84939248308
# No real winner
#
#
#  j=  88
# bayes_factor of log likelihoods between  xTi  and  yTi  =  43.743977152
# No real winner
#
#
#  j=  89
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00530880310893
# Point to  yTi
#
#
#  j=  90
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000173574462602
# Point to  yTi
#
#
#  j=  91
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.13854969604
# No real winner
#
#
#  j=  92
# bayes_factor of log likelihoods between  xTi  and  yTi  =  472755.24472
# Point to  xTi
#
#
#  j=  93
# bayes_factor of log likelihoods between  xTi  and  yTi  =  192912.167537
# Point to  xTi
#
#
#  j=  94
# bayes_factor of log likelihoods between  xTi  and  yTi  =  189.83586739
# Point to  xTi
#
#
#  j=  95
# bayes_factor of log likelihoods between  xTi  and  yTi  =  19.0810828177
# No real winner
#
#
#  j=  96
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000212729451502
# Point to  yTi
#
#
#  j=  97
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00534101932733
# Point to  yTi
#
#
#  j=  98
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00826375706562
# Point to  yTi
#
#
#  j=  99
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.68343163852e-05
# Point to  yTi
#
#
#
#  i=  4
#
# QMD has true operator:  xTx
# QMD has true params :  [0.75]
#
# Redimensionalising
# Before dimensionalising name. Name =  x true_dim =  2
# Model  x  not previously considered -- adding.
# Initialization Ready
# Redimensionalising
# Before dimensionalising name. Name =  y true_dim =  2
# Model  y  not previously considered -- adding.
# Initialization Ready
#
# Running IQLE for model:  x
# Initial time selected > 0.36344774585
# Final time selected > 0.40500275517
# Final Parameters mean and stdev:[-0.7561143   0.51737385]
#
# Running IQLE for model:  y
# Initial time selected > 1.84397995222
# Final time selected > 172.01809784
# Final Parameters mean and stdev:[ 0.23408576  0.07367447]
#
#
#  j=  0
# bayes_factor of log likelihoods between  xTi  and  yTi  =  227403695448.0
# Point to  xTi
#
#
#  j=  1
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3695169120.62
# Point to  xTi
#
#
#  j=  2
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.03142993882e-12
# Point to  yTi
#
#
#  j=  3
# bayes_factor of log likelihoods between  xTi  and  yTi  =  50654613263.3
# Point to  xTi
#
#
#  j=  4
# bayes_factor of log likelihoods between  xTi  and  yTi  =  119644918.602
# Point to  xTi
#
#
#  j=  5
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2661297697.62
# Point to  xTi
#
#
#  j=  6
# bayes_factor of log likelihoods between  xTi  and  yTi  =  108154720370.0
# Point to  xTi
#
#
#  j=  7
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.37773930044e+13
# Point to  xTi
#
#
#  j=  8
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3093339329.09
# Point to  xTi
#
#
#  j=  9
# bayes_factor of log likelihoods between  xTi  and  yTi  =  17.6418577593
# No real winner
#
#
#  j=  10
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000555560555093
# Point to  yTi
#
#
#  j=  11
# bayes_factor of log likelihoods between  xTi  and  yTi  =  28964783408.7
# Point to  xTi
#
#
#  j=  12
# bayes_factor of log likelihoods between  xTi  and  yTi  =  130117.053818
# Point to  xTi
#
#
#  j=  13
# bayes_factor of log likelihoods between  xTi  and  yTi  =  124647462.771
# Point to  xTi
#
#
#  j=  14
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.14034051198e+12
# Point to  xTi
#
#
#  j=  15
# bayes_factor of log likelihoods between  xTi  and  yTi  =  26408220922.9
# Point to  xTi
#
#
#  j=  16
# bayes_factor of log likelihoods between  xTi  and  yTi  =  23880617.2715
# Point to  xTi
#
#
#  j=  17
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.71234936495e-07
# Point to  yTi
#
#
#  j=  18
# bayes_factor of log likelihoods between  xTi  and  yTi  =  9211749800.35
# Point to  xTi
#
#
#  j=  19
# bayes_factor of log likelihoods between  xTi  and  yTi  =  444535.098177
# Point to  xTi
#
#
#  j=  20
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1116461.48424
# Point to  xTi
#
#
#  j=  21
# bayes_factor of log likelihoods between  xTi  and  yTi  =  7.15941134094e+12
# Point to  xTi
#
#
#  j=  22
# bayes_factor of log likelihoods between  xTi  and  yTi  =  53744035435.2
# Point to  xTi
#
#
#  j=  23
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1746079.7162
# Point to  xTi
#
#
#  j=  24
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4497.46929671
# Point to  xTi
#
#
#  j=  25
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6460.71560619
# Point to  xTi
#
#
#  j=  26
# bayes_factor of log likelihoods between  xTi  and  yTi  =  23058016.8695
# Point to  xTi
#
#
#  j=  27
# bayes_factor of log likelihoods between  xTi  and  yTi  =  139806277403.0
# Point to  xTi
#
#
#  j=  28
# bayes_factor of log likelihoods between  xTi  and  yTi  =  743774.915125
# Point to  xTi
#
#
#  j=  29
# bayes_factor of log likelihoods between  xTi  and  yTi  =  165925900.044
# Point to  xTi
#
#
#  j=  30
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.64679670965e+13
# Point to  xTi
#
#
#  j=  31
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.07846078523e+14
# Point to  xTi
#
#
#  j=  32
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.0175895408119
# Point to  yTi
#
#
#  j=  33
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1140309541.73
# Point to  xTi
#
#
#  j=  34
# bayes_factor of log likelihoods between  xTi  and  yTi  =  104458.097808
# Point to  xTi
#
#
#  j=  35
# bayes_factor of log likelihoods between  xTi  and  yTi  =  30028.9097998
# Point to  xTi
#
#
#  j=  36
# bayes_factor of log likelihoods between  xTi  and  yTi  =  28983407802.0
# Point to  xTi
#
#
#  j=  37
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.60526967716e+16
# Point to  xTi
#
#
#  j=  38
# bayes_factor of log likelihoods between  xTi  and  yTi  =  228.646002103
# Point to  xTi
#
#
#  j=  39
# bayes_factor of log likelihoods between  xTi  and  yTi  =  21422042.5355
# Point to  xTi
#
#
#  j=  40
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.010073909571
# Point to  yTi
#
#
#  j=  41
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2980.50983586
# Point to  xTi
#
#
#  j=  42
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4002340.75142
# Point to  xTi
#
#
#  j=  43
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4530597.48862
# Point to  xTi
#
#
#  j=  44
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.15158025813e+13
# Point to  xTi
#
#
#  j=  45
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.13616205038e+13
# Point to  xTi
#
#
#  j=  46
# bayes_factor of log likelihoods between  xTi  and  yTi  =  44521991.2853
# Point to  xTi
#
#
#  j=  47
# bayes_factor of log likelihoods between  xTi  and  yTi  =  8.74953513545e-07
# Point to  yTi
#
#
#  j=  48
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1880930036.88
# Point to  xTi
#
#
#  j=  49
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1634307.86914
# Point to  xTi
#
#
#  j=  50
# bayes_factor of log likelihoods between  xTi  and  yTi  =  154948348997.0
# Point to  xTi
#
#
#  j=  51
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4513371.76418
# Point to  xTi
#
#
#  j=  52
# bayes_factor of log likelihoods between  xTi  and  yTi  =  19593639500.7
# Point to  xTi
#
#
#  j=  53
# bayes_factor of log likelihoods between  xTi  and  yTi  =  888697.962801
# Point to  xTi
#
#
#  j=  54
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2557122.97721
# Point to  xTi
#
#
#  j=  55
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.000306542961117
# Point to  yTi
#
#
#  j=  56
# bayes_factor of log likelihoods between  xTi  and  yTi  =  99548281.9316
# Point to  xTi
#
#
#  j=  57
# bayes_factor of log likelihoods between  xTi  and  yTi  =  15570.4049283
# Point to  xTi
#
#
#  j=  58
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6112977210.61
# Point to  xTi
#
#
#  j=  59
# bayes_factor of log likelihoods between  xTi  and  yTi  =  7.50631805e+13
# Point to  xTi
#
#
#  j=  60
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.12268627824e+12
# Point to  xTi
#
#
#  j=  61
# bayes_factor of log likelihoods between  xTi  and  yTi  =  24491165.2607
# Point to  xTi
#
#
#  j=  62
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.53959398635e-10
# Point to  yTi
#
#
#  j=  63
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4251839998.11
# Point to  xTi
#
#
#  j=  64
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1627917.22792
# Point to  xTi
#
#
#  j=  65
# bayes_factor of log likelihoods between  xTi  and  yTi  =  38206370841.0
# Point to  xTi
#
#
#  j=  66
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.36324872867e+13
# Point to  xTi
#
#
#  j=  67
# bayes_factor of log likelihoods between  xTi  and  yTi  =  332305522225.0
# Point to  xTi
#
#
#  j=  68
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3124162.83715
# Point to  xTi
#
#
#  j=  69
# bayes_factor of log likelihoods between  xTi  and  yTi  =  98164585954.2
# Point to  xTi
#
#
#  j=  70
# bayes_factor of log likelihoods between  xTi  and  yTi  =  0.00212757497999
# Point to  yTi
#
#
#  j=  71
# bayes_factor of log likelihoods between  xTi  and  yTi  =  16534420.5281
# Point to  xTi
#
#
#  j=  72
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.62678916938e+13
# Point to  xTi
#
#
#  j=  73
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2566694.67742
# Point to  xTi
#
#
#  j=  74
# bayes_factor of log likelihoods between  xTi  and  yTi  =  14153626269.0
# Point to  xTi
#
#
#  j=  75
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.32880758397e+13
# Point to  xTi
#
#
#  j=  76
# bayes_factor of log likelihoods between  xTi  and  yTi  =  690750190512.0
# Point to  xTi
#
#
#  j=  77
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.72886116381e-12
# Point to  yTi
#
#
#  j=  78
# bayes_factor of log likelihoods between  xTi  and  yTi  =  9385170875.53
# Point to  xTi
#
#
#  j=  79
# bayes_factor of log likelihoods between  xTi  and  yTi  =  24515.4072217
# Point to  xTi
#
#
#  j=  80
# bayes_factor of log likelihoods between  xTi  and  yTi  =  10832352.1404
# Point to  xTi
#
#
#  j=  81
# bayes_factor of log likelihoods between  xTi  and  yTi  =  70813818516.3
# Point to  xTi
#
#
#  j=  82
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6043430918.23
# Point to  xTi
#
#
#  j=  83
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3577349.81286
# Point to  xTi
#
#
#  j=  84
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4028.96868405
# Point to  xTi
#
#
#  j=  85
# bayes_factor of log likelihoods between  xTi  and  yTi  =  455.605104336
# Point to  xTi
#
#
#  j=  86
# bayes_factor of log likelihoods between  xTi  and  yTi  =  698.304459509
# Point to  xTi
#
#
#  j=  87
# bayes_factor of log likelihoods between  xTi  and  yTi  =  286392857188.0
# Point to  xTi
#
#
#  j=  88
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1045715.7211
# Point to  xTi
#
#
#  j=  89
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.05286250973e+15
# Point to  xTi
#
#
#  j=  90
# bayes_factor of log likelihoods between  xTi  and  yTi  =  49053659224.7
# Point to  xTi
#
#
#  j=  91
# bayes_factor of log likelihoods between  xTi  and  yTi  =  321478519.948
# Point to  xTi
#
#
#  j=  92
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.70103645604e-11
# Point to  yTi
#
#
#  j=  93
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3250.56044746
# Point to  xTi
#
#
#  j=  94
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6178575.44114
# Point to  xTi
#
#
#  j=  95
# bayes_factor of log likelihoods between  xTi  and  yTi  =  203.965800372
# Point to  xTi
#
#
#  j=  96
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.40561058814e+12
# Point to  xTi
#
#
#  j=  97
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.72593999148e+13
# Point to  xTi
#
#
#  j=  98
# bayes_factor of log likelihoods between  xTi  and  yTi  =  42604426.5141
# Point to  xTi
#
#
#  j=  99
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1965962.31273
# Point to  xTi
#
#
#
#  i=  5
#
# QMD has true operator:  xTx
# QMD has true params :  [0.75]
#
# Redimensionalising
# Before dimensionalising name. Name =  x true_dim =  2
# Model  x  not previously considered -- adding.
# Initialization Ready
# Redimensionalising
# Before dimensionalising name. Name =  y true_dim =  2
# Model  y  not previously considered -- adding.
# Initialization Ready
#
# Running IQLE for model:  x
# Initial time selected > 15.9303131948
# Final time selected > 0.521430056464
# Final Parameters mean and stdev:[-0.07464653  0.56872676]
#
# Running IQLE for model:  y
# Initial time selected > 0.758509177866
# Final time selected > 2.30257149218
# Final Parameters mean and stdev:[-0.36247619  0.15903698]
#
#
#  j=  0
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.32481641176e-13
# Point to  yTi
#
#
#  j=  1
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6.10178475891e-17
# Point to  yTi
#
#
#  j=  2
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.59525072301e-07
# Point to  yTi
#
#
#  j=  3
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.00544461946e-12
# Point to  yTi
#
#
#  j=  4
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.21991834327e-10
# Point to  yTi
#
#
#  j=  5
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.25868679284e-08
# Point to  yTi
#
#
#  j=  6
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.572479488e-15
# Point to  yTi
#
#
#  j=  7
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.43390290652e-09
# Point to  yTi
#
#
#  j=  8
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6.38072719584e-11
# Point to  yTi
#
#
#  j=  9
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.94697429318e-07
# Point to  yTi
#
#
#  j=  10
# bayes_factor of log likelihoods between  xTi  and  yTi  =  8.01500818651e-17
# Point to  yTi
#
#
#  j=  11
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.66508561086e-15
# Point to  yTi
#
#
#  j=  12
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.2443574841e-15
# Point to  yTi
#
#
#  j=  13
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.85326325389e-12
# Point to  yTi
#
#
#  j=  14
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.60639821982e-12
# Point to  yTi
#
#
#  j=  15
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.86199145955e-12
# Point to  yTi
#
#
#  j=  16
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.3239501123e-09
# Point to  yTi
#
#
#  j=  17
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.09160686158e-11
# Point to  yTi
#
#
#  j=  18
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.08767670845e-09
# Point to  yTi
#
#
#  j=  19
# bayes_factor of log likelihoods between  xTi  and  yTi  =  7.0901140542e-12
# Point to  yTi
#
#
#  j=  20
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.14940240435e-13
# Point to  yTi
#
#
#  j=  21
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.24996337488e-16
# Point to  yTi
#
#
#  j=  22
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.56425889111e-16
# Point to  yTi
#
#
#  j=  23
# bayes_factor of log likelihoods between  xTi  and  yTi  =  9.51368262498e-11
# Point to  yTi
#
#
#  j=  24
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.5201158299e-08
# Point to  yTi
#
#
#  j=  25
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.55277516255e-14
# Point to  yTi
#
#
#  j=  26
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.8628933888e-15
# Point to  yTi
#
#
#  j=  27
# bayes_factor of log likelihoods between  xTi  and  yTi  =  7.00733904082e-15
# Point to  yTi
#
#
#  j=  28
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.56307968269e-11
# Point to  yTi
#
#
#  j=  29
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.45294371181e-12
# Point to  yTi
#
#
#  j=  30
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.89768121883e-08
# Point to  yTi
#
#
#  j=  31
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.14816364892e-10
# Point to  yTi
#
#
#  j=  32
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.65617564569e-11
# Point to  yTi
#
#
#  j=  33
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.43703674435e-06
# Point to  yTi
#
#
#  j=  34
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6.19518863341e-13
# Point to  yTi
#
#
#  j=  35
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.90555687635e-12
# Point to  yTi
#
#
#  j=  36
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.01402237931e-11
# Point to  yTi
#
#
#  j=  37
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.72790699097e-14
# Point to  yTi
#
#
#  j=  38
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.60691302363e-14
# Point to  yTi
#
#
#  j=  39
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.33523444088e-07
# Point to  yTi
#
#
#  j=  40
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.77326896328e-18
# Point to  yTi
#
#
#  j=  41
# bayes_factor of log likelihoods between  xTi  and  yTi  =  9.01940571434e-18
# Point to  yTi
#
#
#  j=  42
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.80757802299e-21
# Point to  yTi
#
#
#  j=  43
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.57088085404e-14
# Point to  yTi
#
#
#  j=  44
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.95001628474e-12
# Point to  yTi
#
#
#  j=  45
# bayes_factor of log likelihoods between  xTi  and  yTi  =  8.01643115823e-07
# Point to  yTi
#
#
#  j=  46
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.30342682257e-12
# Point to  yTi
#
#
#  j=  47
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.62911858309e-14
# Point to  yTi
#
#
#  j=  48
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.32603809708e-09
# Point to  yTi
#
#
#  j=  49
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.32405512423e-08
# Point to  yTi
#
#
#  j=  50
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.45940694761e-11
# Point to  yTi
#
#
#  j=  51
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.66735617019e-15
# Point to  yTi
#
#
#  j=  52
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.66457487492e-14
# Point to  yTi
#
#
#  j=  53
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.64449334156e-10
# Point to  yTi
#
#
#  j=  54
# bayes_factor of log likelihoods between  xTi  and  yTi  =  2.36079531566e-06
# Point to  yTi
#
#
#  j=  55
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.06885331112e-11
# Point to  yTi
#
#
#  j=  56
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.59889645372e-18
# Point to  yTi
#
#
#  j=  57
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.34965951966e-20
# Point to  yTi
#
#
#  j=  58
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.65901334231e-13
# Point to  yTi
#
#
#  j=  59
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6.74083696614e-11
# Point to  yTi
#
#
#  j=  60
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.56435464685e-13
# Point to  yTi
#
#
#  j=  61
# bayes_factor of log likelihoods between  xTi  and  yTi  =  4.34608322042e-15
# Point to  yTi
#
#
#  j=  62
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.26832375793e-08
# Point to  yTi
#
#
#  j=  63
# bayes_factor of log likelihoods between  xTi  and  yTi  =  8.56588713931e-17
# Point to  yTi
#
#
#  j=  64
# bayes_factor of log likelihoods between  xTi  and  yTi  =  6.67158886789e-12
# Point to  yTi
#
#
#  j=  65
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.40870292582e-09
# Point to  yTi
#
#
#  j=  66
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.73604208522e-09
# Point to  yTi
#
#
#  j=  67
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.80370386985e-09
# Point to  yTi
#
#
#  j=  68
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.64262898895e-05
# Point to  yTi
#
#
#  j=  69
# bayes_factor of log likelihoods between  xTi  and  yTi  =  9.89143872553e-14
# Point to  yTi
#
#
#  j=  70
# bayes_factor of log likelihoods between  xTi  and  yTi  =  3.2278308499e-10
# Point to  yTi
#
#
#  j=  71
# bayes_factor of log likelihoods between  xTi  and  yTi  =  5.46787677449e-17
# Point to  yTi
#
#
#  j=  72
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.41702012349e-18
# Point to  yTi
#
#
#  j=  73
# bayes_factor of log likelihoods between  xTi  and  yTi  =  1.86017145538e-14
# Point to  yTi
#
#
#  j=  74

# %%
import random
num_exp = 100

#max_dim=2
#dims = range(1,max_dim+1)
#num_qubits=random.choice(dims)

true_op = 'xTx'
generators = ['x', 'y']

qmd = NewQMDClass(initial_op_list=generators, true_operator=true_op)
# qmd.runQMD(num_exp=num_exp, max_branches=2, max_num_qubits=1)
qmd.runIQLE(model='x', num_exp=num_exp)
qmd.runIQLE(model='y', num_exp=num_exp)

for i in range(6):
    qmd.compareModels(model_a_id=0, model_b_id=1)
#### Below: results without exp_ham turned on

# %%
qmd.db

# %%
def inspect_model(name):
    print("\nmodel name: ", name)
    print("experiments done ", qmd.getModelInstance(name).NumExperimentsToDate)
    print("times: ",  qmd.getModelInstance(name).TrackTime)

for mod in ['x', 'y']:
    inspect_model(mod)

# %%
qmd.getModelInstance('xTxTTx').NumExperimentsToDate

# %% [markdown]
# ## Partial trace development

# %%
import hamiltonian_exponentiation as h
def evolve_state(ham, t, input_state):
    # todo : check dimensionality of input state vs hamiltonian
    unitary = h.exp_ham(ham, t)
    return unitary @ input_state
