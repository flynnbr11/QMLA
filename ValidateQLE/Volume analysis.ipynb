# %%
from __future__ import print_function # so print doesn't show brackets
import numpy as np
import itertools as itr

import os as os
import sys as sys 
import pandas as pd
import warnings
import time as time
import random
import pickle
pickle.HIGHEST_PROTOCOL = 2
sys.path.append(os.path.join("..", "Libraries","QML_lib"))
from RedisSettings import *
import Evo as evo
import DataBase 
from QMD import QMD #  class moved to QMD in Library
import QML
import ModelGeneration 
import BayesF
import matplotlib.pyplot as plt
#from pympler import asizeof
import matplotlib.pyplot as plt
paulis = ['x', 'y', 'z'] # will be chosen at random. or uncomment below and comment within loop to hard-set

import viz_library as v
import time as time 
import argparse

parser = argparse.ArgumentParser(description='Pass variables for (I)QLE.')

import warnings
warnings.filterwarnings("ignore")
# Out:
# Using host name  localhost

# %%
qmd=pickle.load(open('qmd_class.p', "rb"))

# %%
qmd.db
# Out:
#                                          <Name> Completed  Epoch_Start  \
# 0                                           xTi      True          0.0
# 1                                           yTi      True          0.0
# 2                                           zTi      True          0.0
# 3                                      yTiPPxTi      True          0.0
# 4                                      yTiPPzTi      True          0.0
# 5                                 yTiPPxTiPPzTi      True          0.0
# 6                            yTiPPxTiPPzTiPPxTx      True          0.0
# 7                            yTiPPxTiPPzTiPPyTy      True          0.0
# 8                            yTiPPxTiPPzTiPPzTz      True          0.0
# 9                       yTiPPxTiPPzTiPPzTzPPxTx      True          0.0
# 10                      yTiPPxTiPPzTiPPzTzPPyTy      True          0.0
# 11                 yTiPPxTiPPzTiPPzTzPPxTxPPyTy      True          0.0
# 12            yTiPPxTiPPzTiPPzTzPPxTxPPyTyPPzTy      True          0.0
# 13            yTiPPxTiPPzTiPPzTzPPxTxPPyTyPPxTy      True          0.0
# 14            yTiPPxTiPPzTiPPzTzPPxTxPPyTyPPyTx      True          0.0
# 15       yTiPPxTiPPzTiPPzTzPPxTxPPyTyPPzTyPPyTx      True          0.0
# 16       yTiPPxTiPPzTiPPzTzPPxTxPPyTyPPzTyPPxTz      True          0.0
# 17       yTiPPxTiPPzTiPPzTzPPxTxPPyTyPPzTyPPxTy      True          0.0
# 18  yTiPPxTiPPzTiPPzTzPPxTxPPyTyPPzTyPPxTyPPyTx      True          0.0
# 19  yTiPPxTiPPzTiPPzTzPPxTxPPyTyPPzTyPPxTyPPyTz      True          0.0
# 20  yTiPPxTiPPzTiPPzTzPPxTxPPyTyPPzTyPPxTyPPzTx      True          0.0
#
#     ModelID                             Operator_Instance  \
# 0       0.0  <DataBase.operator object at 0x7f5aee8e9588>
# 1       1.0  <DataBase.operator object at 0x7f5aee8e95c0>
# 2       2.0  <DataBase.operator object at 0x7f5aee8e95f8>
# 3       3.0  <DataBase.operator object at 0x7f5aee8e9630>
# 4       4.0  <DataBase.operator object at 0x7f5aee8e9668>
# 5       5.0  <DataBase.operator object at 0x7f5aee8e96a0>
# 6       6.0  <DataBase.operator object at 0x7f5aee8e96d8>
# 7       7.0  <DataBase.operator object at 0x7f5aee8e9710>
# 8       8.0  <DataBase.operator object at 0x7f5aee8e9748>
# 9       9.0  <DataBase.operator object at 0x7f5aee8e9780>
# 10     10.0  <DataBase.operator object at 0x7f5aee8e97b8>
# 11     11.0  <DataBase.operator object at 0x7f5aee8e97f0>
# 12     12.0  <DataBase.operator object at 0x7f5aee8e9828>
# 13     13.0  <DataBase.operator object at 0x7f5aee8e9860>
# 14     14.0  <DataBase.operator object at 0x7f5aee8e9898>
# 15     15.0  <DataBase.operator object at 0x7f5aee8e98d0>
# 16     16.0  <DataBase.operator object at 0x7f5aee8e9908>
# 17     17.0  <DataBase.operator object at 0x7f5aee8e9940>
# 18     18.0  <DataBase.operator object at 0x7f5aee8e9978>
# 19     19.0  <DataBase.operator object at 0x7f5aee8e99b0>
# 20     20.0  <DataBase.operator object at 0x7f5aee8e99e8>
#
#                    Reduced_Model_Class_Instance       Status  branchID
# 0   <QML.reducedModel object at 0x7f5aee8e9a20>  Deactivated       0.0
# 1   <QML.reducedModel object at 0x7f5aee8f1780>       Active       0.0
# 2   <QML.reducedModel object at 0x7f5aee8fc438>  Deactivated       0.0
# 3   <QML.reducedModel object at 0x7f5aee9070f0>       Active       1.0
# 4   <QML.reducedModel object at 0x7f5aee90cda0>  Deactivated       1.0
# 5   <QML.reducedModel object at 0x7f5aee897a58>       Active       2.0
# 6   <QML.reducedModel object at 0x7f5aee8a2748>  Deactivated       3.0
# 7   <QML.reducedModel object at 0x7f5aee8af470>  Deactivated       3.0
# 8   <QML.reducedModel object at 0x7f5aee8bb198>       Active       3.0
# 9   <QML.reducedModel object at 0x7f5aee8c1e80>       Active       4.0
# 10  <QML.reducedModel object at 0x7f5aee8cebe0>  Deactivated       4.0
# 11  <QML.reducedModel object at 0x7f5aee859940>       Active       5.0
# 12  <QML.reducedModel object at 0x7f5aee8676d8>       Active       6.0
# 13  <QML.reducedModel object at 0x7f5aee8754a8>  Deactivated       6.0
# 14  <QML.reducedModel object at 0x7f5aee885278>  Deactivated       6.0
# 15  <QML.reducedModel object at 0x7f5aee814048>  Deactivated       7.0
# 16  <QML.reducedModel object at 0x7f5aee81de10>  Deactivated       7.0
# 17  <QML.reducedModel object at 0x7f5aee827c18>       Active       7.0
# 18  <QML.reducedModel object at 0x7f5aee836a20>  Deactivated       8.0
# 19  <QML.reducedModel object at 0x7f5aee845860>  Deactivated       8.0
# 20  <QML.reducedModel object at 0x7f5aee7d36a0>       Active       8.0

# %%
test_mtx = [[10, 3], [4,3]]

# %%
v.hinton(test_mtx, grid=True , skip_diagonal=False, max_value=4)

# %%
qmd.BranchRankings

# %%
qmd.reducedModelInstanceFromID(9).BayesFactors

# %%
all_bayes_factors = {}
for i in range(qmd.HighestModelID):
    all_bayes_factors[i] = qmd.reducedModelInstanceFromID(i).BayesFactors

# %%
all_bayes_factors

# %%
qmd.db

# %%
qmd.ModelNameIDs

# %%
mylist=[0,1,2,3,4,5]

# %%
import random
random.choice(mylist)
